# %% [markdown]
# # Lab 5: Leveraging Open Data from Wikipedia for LLM Prompt Engineering
#
# ## Overview
# This lab demonstrates how to extract structured data from Wikipedia pages and use it to create effective prompts for Large Language Models (LLMs). You'll learn to work with real-world financial data, process it programmatically, and engineer prompts for various AI tasks.
#
# ## Learning Objectives
# - ✓ Extract financial index components from Wikipedia
# - ✓ Retrieve company infobox data programmatically
# - ✓ Build structured datasets from semi-structured web data
# - ✓ Design effective LLM prompts for different tasks
# - ✓ Process and clean text data for AI consumption
# - ✓ Create reusable prompt templates and utilities

# %% [markdown]
# ## Part 1: Data Extraction from Wikipedia
#
# ### What is a Financial Index?
# A financial index is a composite measure of a subset of companies in a specific market or sector. Examples include:
# - **S&P 500**: 500 largest US companies
# - **EURO STOXX 50**: 50 largest Eurozone companies
# - **DAX**: 40 largest German companies
#
# ### Your Task
# 1. **Identify components**: Extract the list of companies in each index from Wikipedia
# 2. **Gather company data**: Retrieve detailed information (infoboxes) from each company's Wikipedia page
# 3. **Build a dataset**: Combine all data into structured format suitable for LLM processing
# 4. **Engineer prompts**: Create effective prompts that leverage this data for AI tasks
#
# ### Data Sources
# - **Index components**: Wikipedia articles listing index members
# - **Company data**: Wikipedia infoboxes (structured data boxes on company pages)
# - **Dump file**: Optional - for advanced analysis of full Wikipedia articles

# %% [markdown]
# ### Optional: Full Wikipedia Dump
# For advanced analysis, you can download the complete Wikipedia dump from:
# - **Link**: https://dumps.wikimedia.org/enwiki/
# - **File**: `enwiki-latest-pages-articles-multistream-index.txt.bz2`
# - **Use case**: Full-text search, article history analysis, or complete data scraping
# - **Note**: Very large files (100+ GB) - requires significant storage and processing power
#
# For this lab, we'll focus on extracting specific data via the Wikipedia API, which is more efficient.

# %%
# !uv pip install pandas pathlib typing tqdm wptools loguru numpy
# Out:
# Using Python 3.12.12 environment at: /usr
# Resolved 15 packages in 272ms
# Prepared 6 packages in 130ms
# Installed 6 packages in 17ms
#  + html2text==2025.4.15
#  + loguru==0.7.3
#  + pathlib==1.0.1
#  + pycurl==7.45.7
#  + typing==3.10.0.0
#  + wptools==0.4.17

# %%
# ============================================================================
# IMPORTS & SETUP
# ============================================================================
# These libraries enable us to work with Wikipedia data

import pandas as pd              # Data manipulation and analysis
import urllib.request           # HTTP requests to Wikipedia
from pathlib import Path        # Cross-platform file path handling
from typing import Union, Dict  # Type hints for better code clarity
from tqdm import tqdm          # Progress bars for long operations
import wptools               # Wikipedia parsing (infobox extraction)
from loguru import logger       # Enhanced logging
import json                     # Working with JSON data
import numpy as np             # Numerical operations
import re                       # Regular expressions for text cleaning

# %% [markdown]
# ## Step 1: Extract Index Components from Wikipedia
#
# ### Task: Extract Company Lists
# We'll extract the list of companies that make up each financial index directly from Wikipedia.
#
# ### Indices We're Covering:
# 1. **S&P 500** (USA) - 500 largest US companies
# 2. **EURO STOXX 50** (Europe) - 50 largest Eurozone companies
# 3. **CAC 40** (France) - 40 largest French companies
# 4. **DAX** (Germany) - 40 largest German companies
# 5. **CSI 300** (China) - 300 largest Chinese companies
# 6. **S&P Latin America 40** (Latin America) - 40 major LA companies
# 7. **BSE SENSEX** (India) - 30 largest Indian companies
# 8. **NASDAQ-100** (USA Tech) - 100 largest non-financial NASDAQ companies
#
# ### How It Works:
# - Each index has a Wikipedia article with a table listing its components
# - We'll use `pd.read_html()` to extract all tables from these pages
# - Tables are saved as CSV files for later processing
# - This approach is fast, requires no authentication, and respects Wikipedia's terms

# %%
# ============================================================================
# FUNCTION 1: Extract Tables from Wikipedia
# ============================================================================
# This function downloads tables from Wikipedia articles and saves them locally

def get_index_components(wiki_url: str, save_dir: Union[str, Path],
                         opener: urllib.request.OpenerDirector) -> None:
    """
    Extract all HTML tables from a Wikipedia page and save as CSV files.

    Parameters:
    -----------
    wiki_url : str
        The Wikipedia page URL to scrape (e.g., list of index components)
    save_dir : Union[str, Path]
        Directory where CSV files will be saved
    opener : urllib.request.OpenerDirector
        Custom URL opener with proper User-Agent headers

    Output:
    -------
    Creates CSV files named table_0.csv, table_1.csv, etc. in save_dir
    Each file contains one table from the Wikipedia page

    Example:
    --------
    >>> get_index_components(
    ...     "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies",
    ...     "./data/indices/sp500",
    ...     opener
    ... )
    """
    save_path = Path(save_dir)
    save_path.mkdir(parents=True, exist_ok=True)

    # Install the opener so that pandas.read_html uses it under the hood
    urllib.request.install_opener(opener)

    # Let pandas handle downloading + HTML parsing from the URL
    tables = pd.read_html(wiki_url)

    # Export each table to CSV
    for idx, df in enumerate(tables):
        out_file = save_path / f"table_{idx}.csv"
        df.to_csv(out_file, index=False)

    logger.info(
        "Saved %d tables from %s into directory %s",
        len(tables),
        wiki_url,
        save_path
    )

# %%
# ============================================================================
# SETUP: Configure Wikipedia Index URLs and HTTP Headers
# ============================================================================

# Dictionary mapping index names to their Wikipedia article URLs
# These URLs contain tables with the company components of each index
indices = {
    "sp500": "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies",
    "eurostoxx50": "https://en.wikipedia.org/wiki/EURO_STOXX_50",
    "cac40": "https://en.wikipedia.org/wiki/CAC_40",
    "dax": "https://en.wikipedia.org/wiki/DAX",
    "csi300": "https://en.wikipedia.org/wiki/CSI_300_Index",
    "spla40": "https://en.wikipedia.org/wiki/S%26P_Latin_America_40",
    "bsesensex": "https://en.wikipedia.org/wiki/BSE_SENSEX",
    "nasdaq100": "https://en.wikipedia.org/wiki/Nasdaq-100",
}

# IMPORTANT: Configure HTTP headers to identify our bot to Wikipedia
# This is REQUIRED for ethical web scraping - identify yourself!
# Wikipedia may block requests without proper User-Agent headers

opener = urllib.request.build_opener()
opener.addheaders = [
    ("User-Agent", "MyResearchBot/1.0 (contact@example.com)")  # Identify your bot
]
urllib.request.install_opener(opener)

# %%
# ============================================================================
# EXECUTION: Download Index Components
# ============================================================================
# Loop through each index and extract its company components from Wikipedia
# This may take a few minutes depending on internet speed

for index_name, wiki_url in tqdm(indices.items(), desc="Downloading indices"):
    save_dir = Path(f"./data/indices/{index_name}")
    get_index_components(wiki_url, save_dir, opener)
# Out:
# Downloading indices:   0%|          | 0/8 [00:00<?, ?it/s]2025-11-29 17:51:26.970 | INFO     | __main__:get_index_components:47 - Saved %d tables from %s into directory %s
# Downloading indices:  12%|█▎        | 1/8 [00:00<00:01,  3.65it/s]2025-11-29 17:51:27.803 | INFO     | __main__:get_index_components:47 - Saved %d tables from %s into directory %s
# Downloading indices:  25%|██▌       | 2/8 [00:01<00:03,  1.66it/s]2025-11-29 17:51:28.137 | INFO     | __main__:get_index_components:47 - Saved %d tables from %s into directory %s
# Downloading indices:  38%|███▊      | 3/8 [00:01<00:02,  2.08it/s]2025-11-29 17:51:28.443 | INFO     | __main__:get_index_components:47 - Saved %d tables from %s into directory %s
# Downloading indices:  50%|█████     | 4/8 [00:01<00:01,  2.43it/s]2025-11-29 17:51:28.528 | INFO     | __main__:get_index_components:47 - Saved %d tables from %s into directory %s
# 2025-11-29 17:51:28.568 | INFO     | __main__:get_index_components:47 - Saved %d tables from %s into directory %s
# Downloading indices:  75%|███████▌  | 6/8 [00:01<00:00,  4.42it/s]2025-11-29 17:51:28.734 | INFO     | __main__:get_index_components:47 - Saved %d tables from %s into directory %s
# Downloading indices:  88%|████████▊ | 7/8 [00:02<00:00,  4.76it/s]2025-11-29 17:51:28.875 | INFO     | __main__:get_index_components:47 - Saved %d tables from %s into directory %s
# Downloading indices: 100%|██████████| 8/8 [00:02<00:00,  3.67it/s]

# %% [markdown]
# ## Step 2: Extract Company Infoboxes from Wikipedia
#
# ### What are Infoboxes?
# Wikipedia infoboxes are structured data boxes that appear on the right side of articles. They contain:
# - Company name and alternative names
# - Industry classification
# - Founded date and location
# - Key executives
# - Headquarters location
# - Number of employees
# - Revenue and financial metrics
# - Official website URLs
# - Stock exchange listings
# - And much more...
#
# ### Why Infoboxes?
# - **Structured data**: Unlike article body text, infoboxes are semi-structured
# - **Consistency**: Fields follow a template across similar articles
# - **Ease of extraction**: Wikipedia APIs can parse infoboxes directly
# - **Rich context**: Perfect for LLM prompts - contains exactly the info LLMs need
#
# ### Process
# 1. Use the `wptools` library to fetch each company's Wikipedia page
# 2. Extract the infobox (structured data) from the page parse
# 3. Save as JSON for flexibility and later processing
# 4. Handle errors gracefully (some companies may not have Wikipedia pages)

# %%
# ============================================================================
# EXAMPLE: Extract a Single Company Infobox
# ============================================================================
# This example shows the process for one company (3M) from S&P 500
# In production, we'd loop this for all companies


def save_company_infobox(company_name: str,
                         save_dir: Union[str, Path] = "./data/infoboxes/sp500") -> None:
    """
    Fetch a company's Wikipedia infobox and save it as JSON.

    Parameters
    ----------
    company_name : str
        Name of the company as used on Wikipedia (e.g., "3M").
    save_dir : Union[str, Path], optional
        Directory where the infobox JSON will be stored.
    """
    save_path = Path(save_dir)
    save_path.mkdir(parents=True, exist_ok=True)

    try:
        # Build and parse the Wikipedia page in one chained call
        page = wptools.page(company_name, silent=True).get_parse()

        # Safely retrieve the infobox dict (fallback to empty if missing)
        infobox = page.data.get("infobox") or {}

        # Construct JSON output path
        json_file = save_path / f"{company_name}.json"
        with json_file.open("w", encoding="utf-8") as f:
            json.dump(infobox, f, indent=2, ensure_ascii=False)

        logger.info("Infobox for %s saved to %s", company_name, json_file)

    except Exception as exc:
        logger.error("Error extracting infobox for %s: %s", company_name, exc)


# Example usage:
save_company_infobox("3M", "./data/infoboxes/sp500")
# Out:
# 2025-11-29 17:51:34.395 | INFO     | __main__:save_company_infobox:35 - Infobox for %s saved to %s

# %%
# ============================================================================
# DISPLAY: View the Extracted Infobox
# ============================================================================
# This shows what data we extracted from Wikipedia

# Load and display the saved infobox

def show_infobox(company_name: str, base_dir: str = "./data/infoboxes/sp500") -> None:
    """
    Load and display a company's infobox from a JSON file.
    """
    json_path = Path(base_dir) / f"{company_name}.json"

    try:
        with json_path.open("r", encoding="utf-8") as f:
            infobox_data = json.load(f)
    except FileNotFoundError:
        print(f"Infobox file not found for {company_name}. Run the extraction step first.")
        return

    print(f"Infobox for {company_name}\n")
    print(f"Total fields extracted: {len(infobox_data)}\n")

    # Iterate over fields and print them
    for key, value in infobox_data.items():
        print(f"{key}: {value}")


# Example usage:
show_infobox("3M")
# Out:
# Infobox for 3M
#
# Total fields extracted: 24
#
# name: 3M Company
# logo: 3M wordmark.svg
# logo_size: 175px
# image: 3-M Building Maplewood MN1.jpg
# image_size: 250px
# image_caption: 3M headquarters in [[Maplewood, Minnesota]]
# former_name: Minnesota Mining and Manufacturing Company (1902–2002)
# type: [[Public company|Public]]
# traded_as: {{Unbulleted list|New York Stock Exchange|MMM|[[Dow Jones Industrial Average|DJIA]] component|[[S&P 100]] component|[[S&P 500]] component}} {{New York Stock Exchange|MMM}}
# ISIN: {{ISIN|sl|=|n|pl|=|y|US88579Y1010}}
# industry: [[Conglomerate (company)|Conglomerate]]
# foundation: {{Start date and age|1902|6|13}} in [[Two Harbors, Minnesota]], U.S.
# founders: {{Unbulleted list|J. Danley Budd|Henry S. Bryan|William A. McGonagle|John Dwan|Hermon W. Cable | Charles Simmons|ref|{{cite web |url=https://www.3m.com.au/3M/en_AU/company-au/news-releases/full-story/?storyid=51f5cfac-3ea9-4a98-a406-e2b955c3fd40 |title=It all started with a rock |date=June 11, 2021 |work=3M Australia |access-date=March 9, 2022}}|</ref>}}
# location_city: [[Maplewood, Minnesota]]
# location_country: U.S.
# area_served: Worldwide
# key_people: {{plainlist|
# * [[Michael F. Roman]] (chairman)
# * [[William M. Brown (businessman)|William M. Brown]] (CEO)|ref|{{citation|url=https://www.manufacturingdive.com/news/3m-ceo-william-brown-executive-chair-michael-roman/709987/|website=Manufacturing Dive|date=March 12, 2024 |title=3M appoints new CEO }}|</ref>}}
# revenue: {{decrease}} {{US$|24.58 billion|link|=|yes}} (2024)
# operating_income: {{increase}} {{US$|4.822 billion}} (2024)
# net_income: {{increase}} {{US$|4.173 billion}} (2024)
# assets: {{decrease}} {{US$|39.87 billion}} (2024)
# equity: {{decrease}} {{US$|3.842 billion}} (2024)
# num_employees: {{circa|61,500}} (2024)
# website: {{URL|3m.com}}

# %% [markdown]
# ## Step 3: Aggregate Infoboxes into Databases
#
# ### What We're Building
# We're converting individual JSON files (one per company) into consolidated CSV databases (one per index).
#
# ### Why?
# - **Easier analysis**: CSV format works with pandas, Excel, and most analysis tools
# - **Efficiency**: One file per index instead of hundreds of individual JSON files
# - **Standardization**: Creates a uniform dataset structure for LLM processing
#
# ### Process
# 1. Read all JSON infobox files for an index from disk
# 2. Convert each JSON to a DataFrame row
# 3. Concatenate all rows into a single DataFrame
# 4. Save as CSV with proper encoding
#
# ### Notes for Future Enhancement
# - The infoboxes contain many fields beyond what we use now (URLs, images, etc.)
# - Future work could extract and leverage additional information
# - This foundation allows flexible data extraction later

# %%
# ============================================================================
# EXECUTION: Merge All Infoboxes into Index Databases
# ============================================================================
# Loop through each index folder and consolidate all JSON infoboxes into CSV

def build_infobox_databases(
    infoboxes_base: Union[str, Path] = "./data/infoboxes",
    output_dir: Union[str, Path] = "./data/databases"
) -> None:
    """
    Merge all company infobox JSON files into per-index CSV databases.

    Parameters
    ----------
    infoboxes_base : Union[str, Path]
        Base directory containing one subfolder per index
        (e.g. ./data/infoboxes/sp500, ./data/infoboxes/nasdaq100, ...).
    output_dir : Union[str, Path]
        Directory where aggregated CSV databases will be written.
    """
    infoboxes_base = Path(infoboxes_base)
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)

    # Iterate over all subdirectories (each representing an index)
    for index_dir in infoboxes_base.iterdir():
        if not index_dir.is_dir():
            continue

        index_name = index_dir.name

        # Collect all JSON files in the index directory
        json_files: List[Path] = sorted(index_dir.glob("*.json"))
        if not json_files:
            logger.warning("No JSON files found in %s", index_dir)
            continue

        records: List[Dict] = []

        for json_file in json_files:
            try:
                # Read and parse JSON
                data = json.loads(json_file.read_text(encoding="utf-8"))
                # Store filename stem as a reference to the original company
                data["_source_file"] = json_file.stem
                records.append(data)
            except Exception as exc:
                logger.error("Failed to read %s: %s", json_file, exc)

        if not records:
            logger.warning("No valid records found in %s", index_dir)
            continue

        # Convert list of dicts to DataFrame
        df = pd.DataFrame.from_records(records)

        # Save one CSV per index
        csv_path = output_dir / f"{index_name}_infoboxes.csv"
        df.to_csv(csv_path, index=False, encoding="utf-8")

        logger.info(
            "Aggregated %d companies from %s -> %s",
            len(records),
            index_name,
            csv_path,
        )


# Example usage:
build_infobox_databases("./data/infoboxes", "./data/databases")
# Out:
# 2025-11-29 17:53:15.966 | INFO     | __main__:build_infobox_databases:61 - Aggregated %d companies from %s -> %s

# %% [markdown]
# # New step : complete process for every index

# %%
# ============================================================================
# FUNCTION: Fetch All Company Infoboxes for Any Index
# ============================================================================
import time  # For rate limiting
# Configuration: which table and column contains company names for each index
INDEX_CONFIG: Dict[str, Dict[str, str]] = {
    "sp500":       {"table": "table_1.csv", "column": "Security"},
    "eurostoxx50": {"table": "table_4.csv", "column": "Name"},
    "cac40":       {"table": "table_4.csv", "column": "Company"},
    "dax":         {"table": "table_4.csv", "column": "Company"},
    "csi300":      {"table": "table_3.csv", "column": "Company"},
    "spla40":      {"table": "table_1.csv", "column": "Company name"},
    "bsesensex":   {"table": "table_2.csv", "column": "Company"},
    "nasdaq100":   {"table": "table_4.csv", "column": "Company"},
}


def fetch_index_infoboxes(
    index_name: str,
    indices_base: Union[str, Path] = "./data/indices",
    output_dir: Union[str, Path] = "./data/databases",
    rate_limit: float = 0.5,
) -> pd.DataFrame:
    """
    Fetch Wikipedia infoboxes for all companies in a given index.

    Parameters
    ----------
    index_name : str
        One of: "sp500", "eurostoxx50", "cac40", "dax", "csi300",
                "spla40", "bsesensex", "nasdaq100".
    indices_base : Union[str, Path], optional
        Base directory where index component CSVs are stored.
        e.g. ./data/indices/sp500/table_1.csv
    output_dir : Union[str, Path], optional
        Directory where the aggregated infobox CSV will be written.
    rate_limit : float, optional
        Sleep time (in seconds) between Wikipedia requests.

    Returns
    -------
    pd.DataFrame
        DataFrame containing all successfully fetched infoboxes.
        Also saved as ./data/databases/{index_name}_infoboxes.csv
    """
    if index_name not in INDEX_CONFIG:
        valid = ", ".join(sorted(INDEX_CONFIG.keys()))
        raise ValueError(f"Unknown index: {index_name}. Choose from: {valid}")

    config = INDEX_CONFIG[index_name]

    indices_base = Path(indices_base)
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)

    # Load company list for this index
    table_path = indices_base / index_name / config["table"]
    if not table_path.exists():
        raise FileNotFoundError(f"Index table not found: {table_path}")

    df_companies = pd.read_csv(table_path)
    companies: List[str] = (
        df_companies[config["column"]]
        .dropna()
        .astype(str)
        .unique()
        .tolist()
    )

    logger.info("Index %s: found %d companies", index_name, len(companies))

    records: List[Dict[str, Any]] = []
    failed: List[str] = []

    for company_name in tqdm(companies, desc=f"Fetching {index_name} infoboxes"):
        try:
            # Chain creation and parsing
            page = wptools.page(company_name, silent=True).get_parse()
            infobox = page.data.get("infobox") or {}

            if infobox:
                # Keep track of original company name
                infobox["_company_name"] = company_name
                records.append(infobox)
            else:
                failed.append(company_name)
        except Exception as exc:
            failed.append(company_name)
            logger.debug("Error fetching %s: %s", company_name, exc)

        time.sleep(rate_limit)

    # Convert to DataFrame and save
    df_infoboxes = pd.DataFrame.from_records(records)
    csv_path = output_dir / f"{index_name}_infoboxes.csv"
    df_infoboxes.to_csv(csv_path, index=False, encoding="utf-8")

    logger.info(
        "Index %s: successfully fetched %d infoboxes, failed %d",
        index_name,
        len(records),
        len(failed),
    )
    if failed:
        sample_failed = failed[:10]
        suffix = "..." if len(failed) > 10 else ""
        logger.warning("Some companies failed (%d total): %s%s", len(failed), sample_failed, suffix)
    logger.info("Saved infobox database to %s", csv_path)

    return df_infoboxes

# Example usage:
df_sp500 = fetch_index_infoboxes("sp500")
# Out:
# 2025-11-29 17:53:29.657 | INFO     | __main__:fetch_index_infoboxes:70 - Index %s: found %d companies
# Fetching sp500 infoboxes:   4%|▍         | 19/502 [00:39<15:41,  1.95s/it]API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 2025-11-29 17:54:08.935 | DEBUG    | __main__:fetch_index_infoboxes:89 - Error fetching %s: %s
# Fetching sp500 infoboxes:   4%|▍         | 20/502 [00:39<12:48,  1.60s/it]API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 2025-11-29 17:54:09.714 | DEBUG    | __main__:fetch_index_infoboxes:89 - Error fetching %s: %s
# Fetching sp500 infoboxes:  16%|█▋        | 82/502 [02:38<11:29,  1.64s/it]API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 2025-11-29 17:56:08.535 | DEBUG    | __main__:fetch_index_infoboxes:89 - Error fetching %s: %s
# Fetching sp500 infoboxes:  22%|██▏       | 111/502 [03:32<12:38,  1.94s/it]API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 2025-11-29 17:57:02.615 | DEBUG    | __main__:fetch_index_infoboxes:89 - Error fetching %s: %s
# Fetching sp500 infoboxes:  24%|██▍       | 121/502 [03:55<15:03,  2.37s/it]API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 2025-11-29 17:57:25.285 | DEBUG    | __main__:fetch_index_infoboxes:89 - Error fetching %s: %s
# Fetching sp500 infoboxes:  35%|███▌      | 176/502 [05:44<09:43,  1.79s/it]API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 2025-11-29 17:59:14.220 | DEBUG    | __main__:fetch_index_infoboxes:89 - Error fetching %s: %s
# Fetching sp500 infoboxes:  40%|███▉      | 200/502 [06:33<14:23,  2.86s/it]API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 2025-11-29 18:00:03.371 | DEBUG    | __main__:fetch_index_infoboxes:89 - Error fetching %s: %s
# Fetching sp500 infoboxes:  40%|████      | 201/502 [06:34<11:12,  2.23s/it]API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 2025-11-29 18:00:04.139 | DEBUG    | __main__:fetch_index_infoboxes:89 - Error fetching %s: %s
# Fetching sp500 infoboxes:  44%|████▍     | 221/502 [07:24<13:47,  2.94s/it]API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 2025-11-29 18:00:54.767 | DEBUG    | __main__:fetch_index_infoboxes:89 - Error fetching %s: %s
# Fetching sp500 infoboxes:  45%|████▌     | 226/502 [07:33<08:59,  1.95s/it]API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 2025-11-29 18:01:03.074 | DEBUG    | __main__:fetch_index_infoboxes:89 - Error fetching %s: %s
# Fetching sp500 infoboxes:  46%|████▌     | 230/502 [07:41<09:53,  2.18s/it]API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 2025-11-29 18:01:11.788 | DEBUG    | __main__:fetch_index_infoboxes:89 - Error fetching %s: %s
# Fetching sp500 infoboxes:  49%|████▉     | 246/502 [08:13<07:48,  1.83s/it]API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 2025-11-29 18:01:43.458 | DEBUG    | __main__:fetch_index_infoboxes:89 - Error fetching %s: %s
# Fetching sp500 infoboxes:  57%|█████▋    | 285/502 [09:32<05:50,  1.62s/it]API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 2025-11-29 18:03:02.029 | DEBUG    | __main__:fetch_index_infoboxes:89 - Error fetching %s: %s
# Fetching sp500 infoboxes:  65%|██████▍   | 324/502 [10:48<06:00,  2.03s/it]API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 2025-11-29 18:04:18.049 | DEBUG    | __main__:fetch_index_infoboxes:89 - Error fetching %s: %s
# Fetching sp500 infoboxes:  66%|██████▌   | 331/502 [11:03<06:14,  2.19s/it]API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 2025-11-29 18:04:32.957 | DEBUG    | __main__:fetch_index_infoboxes:89 - Error fetching %s: %s
# Fetching sp500 infoboxes:  66%|██████▌   | 332/502 [11:03<05:00,  1.77s/it]API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 2025-11-29 18:04:33.729 | DEBUG    | __main__:fetch_index_infoboxes:89 - Error fetching %s: %s
# Fetching sp500 infoboxes:  69%|██████▉   | 346/502 [11:31<05:25,  2.09s/it]API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 2025-11-29 18:05:01.742 | DEBUG    | __main__:fetch_index_infoboxes:89 - Error fetching %s: %s
# Fetching sp500 infoboxes:  77%|███████▋  | 386/502 [12:59<05:20,  2.76s/it]API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 2025-11-29 18:06:29.347 | DEBUG    | __main__:fetch_index_infoboxes:89 - Error fetching %s: %s
# Fetching sp500 infoboxes:  82%|████████▏ | 413/502 [13:50<02:51,  1.93s/it]API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 2025-11-29 18:07:20.528 | DEBUG    | __main__:fetch_index_infoboxes:89 - Error fetching %s: %s
# Fetching sp500 infoboxes:  89%|████████▉ | 446/502 [14:52<01:40,  1.79s/it]API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 2025-11-29 18:08:22.567 | DEBUG    | __main__:fetch_index_infoboxes:89 - Error fetching %s: %s
# Fetching sp500 infoboxes:  90%|████████▉ | 450/502 [14:59<01:36,  1.85s/it]API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 2025-11-29 18:08:29.330 | DEBUG    | __main__:fetch_index_infoboxes:89 - Error fetching %s: %s
# Fetching sp500 infoboxes:  96%|█████████▌| 481/502 [16:05<01:06,  3.15s/it]API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 2025-11-29 18:09:35.246 | DEBUG    | __main__:fetch_index_infoboxes:89 - Error fetching %s: %s
# Fetching sp500 infoboxes: 100%|██████████| 502/502 [16:47<00:00,  2.01s/it]
# 2025-11-29 18:10:17.294 | INFO     | __main__:fetch_index_infoboxes:98 - Index %s: successfully fetched %d infoboxes, failed %d
# 2025-11-29 18:10:17.295 | WARNING  | __main__:fetch_index_infoboxes:107 - Some companies failed (%d total): %s%s
# 2025-11-29 18:10:17.296 | INFO     | __main__:fetch_index_infoboxes:108 - Saved infobox database to %s

# %%
fetch_index_infoboxes("nasdaq100")
# Out:
# 2025-11-29 18:10:17.991 | INFO     | __main__:fetch_index_infoboxes:70 - Index %s: found %d companies
# Fetching nasdaq100 infoboxes:   3%|▎         | 3/102 [00:07<03:50,  2.33s/it]API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 2025-11-29 18:10:25.258 | DEBUG    | __main__:fetch_index_infoboxes:89 - Error fetching %s: %s
# Fetching nasdaq100 infoboxes:   4%|▍         | 4/102 [00:07<02:47,  1.71s/it]API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 2025-11-29 18:10:26.045 | DEBUG    | __main__:fetch_index_infoboxes:89 - Error fetching %s: %s
# Fetching nasdaq100 infoboxes:  93%|█████████▎| 95/102 [03:18<00:20,  2.95s/it]API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 2025-11-29 18:13:36.457 | DEBUG    | __main__:fetch_index_infoboxes:89 - Error fetching %s: %s
# Fetching nasdaq100 infoboxes: 100%|██████████| 102/102 [03:29<00:00,  2.05s/it]
# 2025-11-29 18:13:47.076 | INFO     | __main__:fetch_index_infoboxes:98 - Index %s: successfully fetched %d infoboxes, failed %d
# 2025-11-29 18:13:47.077 | WARNING  | __main__:fetch_index_infoboxes:107 - Some companies failed (%d total): %s%s
# 2025-11-29 18:13:47.077 | INFO     | __main__:fetch_index_infoboxes:108 - Saved infobox database to %s
#                                      name  \
# 0                              Adobe Inc.
# 1            Advanced Micro Devices, Inc.
# 2                            Airbnb, Inc.
# 3   American Electric Power Company, Inc.
# 4                              Amgen Inc.
# ..                                    ...
# 93    Vertex Pharmaceuticals Incorporated
# 94           Warner Bros. Discovery, Inc.
# 95                                    NaN
# 96                       Xcel Energy Inc.
# 97                          Zscaler, Inc.
#
#                                                  logo  \
# 0   [[File:Adobe Corporate wordmark.svg|frameless|...
# 1   [[File:AMD Logo.svg|frameless|upright=1.1|clas...
# 2                                Airbnb Logo Bélo.svg
# 3                               AEP-Logo-Red-Gray.svg
# 4                                           Amgen.svg
# ..                                                ...
# 93                                    Vertex logo.svg
# 94                         Warner Bros. Discovery.svg
# 95                                   Workday logo.svg
# 96                                    Xcel-energy.svg
# 97                                   Zscaler logo.svg
#
#                                                 image image_upright  \
# 0                        Adobe World Headquarters.jpg           1.1
# 1   2485 Augustine Drive headquarters in Santa Cla...           1.1
# 2                888 Brannan, San Francisco, 2016.jpg           NaN
# 3                                  AEP Building 1.jpg           NaN
# 4                               Amgenheadquarters.jpg           NaN
# ..                                                ...           ...
# 93                                                NaN           NaN
# 94                                                NaN           NaN
# 95                           Workday Headquarters.jpg           NaN
# 96                              ExcelEnergyDenver.jpg           NaN
# 97                                                NaN           NaN
#
#                                         image_caption trading_name  \
# 0   [[Adobe World Headquarters]] in [[San Jose, Ca...        Adobe
# 1   Headquarters in [[Santa Clara, California]], i...          NaN
# 2                  Headquarters at 888 Brannan Street          NaN
# 3   [[AEP Building]], the company's headquarters i...          NaN
# 4           Headquarters in Thousand Oaks, California          NaN
# ..                                                ...          ...
# 93                                                NaN          NaN
# 94  WBD's headquarters in 230 [[Park Avenue South]...          NaN
# 95             Headquarters in Pleasanton, California          NaN
# 96  1800 Larimer, Xcel Energy Regional Headquarter...          NaN
# 97                                                NaN          NaN
#
#                                former_name                       type  \
# 0   Adobe Systems Incorporated (1982–2018)  [[Public company|Public]]
# 1                                      NaN  [[Public company|Public]]
# 2                                      NaN  [[Public company|Public]]
# 3                                      NaN  [[Public company|Public]]
# 4                                      NaN  [[Public company|Public]]
# ..                                     ...                        ...
# 93                                     NaN  [[Public company|Public]]
# 94                                     NaN  [[Public company|Public]]
# 95                                     NaN  [[Public company|Public]]
# 96                                     NaN  [[Public company|Public]]
# 97                       SafeChannel, Inc.  [[Public company|Public]]
#
#                                             traded_as  \
# 0   {{Unbulleted list|NASDAQ|ADBE|[[Nasdaq-100]] c...
# 1   {{Unbulleted list\n  | |NASDAQ|AMD|\n  | [[Nas...
# 2   {{ubl|NASDAQ|ABNB| (Class A)|[[Nasdaq-100]] co...
# 3   {{ubl|NASDAQ|AEP|[[DJUA]] component|[[Nasdaq-1...
# 4   {{unbulleted list|NASDAQ|AMGN|[[Nasdaq-100]] c...
# ..                                                ...
# 93  {{ubl|NASDAQ|VRTX|[[Nasdaq-100]] component|[[S...
# 94  {{ublist\n| |NASDAQ|WBD| (Series A)\n| [[Nasda...
# 95  {{ubl| class|=|nowrap\n | |NASDAQ|WDAY| (Class...
# 96  {{ubl|NASDAQ|XEL|[[DJUA]] component|[[Nasdaq-1...
# 97  {{ubl|NASDAQ|ZS|[[Nasdaq-100]] component}} {{N...
#
#                                              industry  ... locations members  \
# 0                                        [[Software]]  ...       NaN     NaN
# 1   {{ubl|[[Semiconductor industry|Semiconductor]]...  ...       NaN     NaN
# 2                                         [[Lodging]]  ...       NaN     NaN
# 3             [[Electric Utility|Electric utilities]]  ...       NaN     NaN
# 4                                   [[Biotechnology]]  ...       NaN     NaN
# ..                                                ...  ...       ...     ...
# 93  {{ubl|[[Pharmaceuticals]] | [[Biotherapy|Bioth...  ...       NaN     NaN
# 94  {{ublist\n| [[Media conglomerate|Media]]\n| [[...  ...       NaN     NaN
# 95  {{ubl|[[Cloud computing]]|[[Enterprise softwar...  ...       NaN     NaN
# 96                       [[Public utility|Utilities]]  ...       NaN     NaN
# 97  [[Network security]], [[computer security]], [...  ...       NaN     NaN
#
#    members_year                                         production defunct  \
# 0           NaN                                                NaN     NaN
# 1           NaN                                                NaN     NaN
# 2           NaN                                                NaN     NaN
# 3           NaN                                                NaN     NaN
# 4           NaN                                                NaN     NaN
# ..          ...                                                ...     ...
# 93          NaN                                                NaN     NaN
# 94          NaN                                                NaN     NaN
# 95          NaN                                                NaN     NaN
# 96          NaN  {{ubl|Electric: 114.98 [[TWh]]|Natural Gas: 40...     NaN
# 97          NaN                                                NaN     NaN
#
#    fate successor native_name logo_class genre
# 0   NaN       NaN         NaN        NaN   NaN
# 1   NaN       NaN         NaN        NaN   NaN
# 2   NaN       NaN         NaN        NaN   NaN
# 3   NaN       NaN         NaN        NaN   NaN
# 4   NaN       NaN         NaN        NaN   NaN
# ..  ...       ...         ...        ...   ...
# 93  NaN       NaN         NaN        NaN   NaN
# 94  NaN       NaN         NaN        NaN   NaN
# 95  NaN       NaN         NaN        NaN   NaN
# 96  NaN       NaN         NaN        NaN   NaN
# 97  NaN       NaN         NaN        NaN   NaN
#
# [98 rows x 70 columns]

# %%
fetch_index_infoboxes("cac40")
# Out:
# 2025-11-29 18:13:47.117 | INFO     | __main__:fetch_index_infoboxes:70 - Index %s: found %d companies
# Fetching cac40 infoboxes: 100%|██████████| 40/40 [01:29<00:00,  2.24s/it]
# 2025-11-29 18:15:16.916 | INFO     | __main__:fetch_index_infoboxes:98 - Index %s: successfully fetched %d infoboxes, failed %d
# 2025-11-29 18:15:16.916 | WARNING  | __main__:fetch_index_infoboxes:107 - Some companies failed (%d total): %s%s
# 2025-11-29 18:15:16.917 | INFO     | __main__:fetch_index_infoboxes:108 - Saved infobox database to %s
#                                                  name  \
# 0                                          Accor S.A.
# 1                                    Air Liquide S.A.
# 2                                           Airbus SE
# 3                                  ArcelorMittal S.A.
# 4                                            AXA S.A.
# 5                                                 NaN
# 6                                       Bouygues S.A.
# 7                                 Bureau Veritas S.A.
# 8                                        Capgemini SE
# 9                                      Carrefour S.A.
# 10                              Crédit Agricole Group
# 11                                        Danone S.A.
# 12                               Dassault Systèmes SE
# 13                                         Edenred SE
# 14                                           Engie SA
# 15                              EssilorLuxottica S.A.
# 16                             Eurofins Scientific SE
# 17                          Hermès International S.A.
# 18                                        Kering S.A.
# 19                                       L'Oréal S.A.
# 20                LVMH Moët Hennessy Louis Vuitton SE
# 21  Compagnie Générale des Établissements Michelin...
# 22                                 Pernod Ricard S.A.
# 23                               Publicis Groupe S.A.
# 24                                       Renault S.A.
# 25                                        Safran S.A.
# 26                     Compagnie de Saint-Gobain S.A.
# 27                                        Sanofi S.A.
# 28                              Schneider Electric SE
# 29                              Société Générale S.A.
# 30                                    Stellantis N.V.
# 31                              STMicroelectronics NV
# 32                                 Teleperformance SE
# 33                                  Thales of Miletus
# 34                                   TotalEnergies SE
# 35                       Unibail-Rodamco-Westfield SE
# 36                          Veolia Environnement S.A.
#
#                                                  logo     logo_alt logo_size  \
# 0                                      Accor logo.svg   Accor logo       150
# 1               Air Liquide - logo (France, 2017).svg          NaN     250px
# 2        Airbus Logo 2017.svg {{!}} class=skin-invert          NaN     180px
# 3                                   ArcelorMittal.svg          NaN     200px
# 4                                        AXA Logo.svg          NaN     165px
# 5                                     BNP Paribas.svg          NaN      50px
# 6                                        Bouygues.svg          NaN     200px
# 7                                  Bureau Veritas.svg          NaN     150px
# 8                              Capgemini New logo.svg          NaN     250px
# 9                                Carrefour_Groupe.svg          NaN       NaN
# 10                                Crédit Agricole.svg          NaN     150px
# 11                                                NaN          NaN       NaN
# 12                         Dassault Systèmes logo.svg          NaN       NaN
# 13                                   Edenred logo.svg          NaN       NaN
# 14                                                NaN          NaN       NaN
# 15  [[File:Logo EssilorLuxottica.svg|frameless|cla...          NaN       NaN
# 16                       Eurofins Scientific Logo.svg          NaN       NaN
# 17                                         Hermès.svg  Hermès logo       NaN
# 18  [[File:Kering logo.svg|frameless|class=skin-in...          NaN       NaN
# 19  [[File:L'Oréal logo.svg|frameless|250px|class=...          NaN       NaN
# 20  [[File:LVMH wordmark.svg|frameless|class=skin-...          NaN       NaN
# 21                                Michelin (2017).svg          NaN       NaN
# 22                        Pernod Ricard logo 2019.svg          NaN       NaN
# 23                                  Publicis logo.svg          NaN       NaN
# 24  [[File:2021 Renault Group logo.svg|frameless|c...          NaN     200px
# 25                                    Safran_logo.svg          NaN     250px
# 26                              Saint-Gobain logo.svg          NaN       NaN
# 27                                    Sanofi-2022.svg          NaN       NaN
# 28         [[File:Schneider Electric 2007.svg|250px]]          NaN       NaN
# 29               [[Image:Société Générale.svg|220px]]          NaN       NaN
# 30                                     Stellantis.svg          NaN       NaN
# 31                            ST_logo_2020_blue_V.svg          NaN     120px
# 32  [[File:TPlogo2025.svg|frameless|upright=0.45|c...          NaN     250px
# 33                                                NaN          NaN       NaN
# 34                             TotalEnergies logo.svg          NaN       NaN
# 35                 Unibail-Rodamco-Westfield_logo.svg          NaN     250px
# 36                     [[File:Veolia logo.svg|250px]]          NaN       NaN
#
#                                            foundation  \
# 0   {{start date and age|1967|df|=|yes}} <br />[[P...
# 1                         {{start date and age|1902}}
# 2                                                 NaN
# 3                         {{start date and age|2007}}
# 4                         {{Start date and age|1921}}
# 5   * {{start date and age|df|=|yes|1822|12|13}} C...
# 6                         {{start date and age|1952}}
# 7                         {{start date and age|1828}}
# 8      {{Start date and age|df|=|yes|1 October 1967}}
# 9            {{start date and age|df|=|yes|1958|1|1}}
# 10         {{Start date and age|df|=|yes|1894|11|05}}
# 11  '''Company:''' {{start date and age|1966}} (as...
# 12                        {{Start date and age|1981}}
# 13                          {{Start date|2010|06|29}}
# 14   {{Start date and years ago|df|=|yes|2008|07|22}}
# 15                                                NaN
# 16                        {{Start date and age|1987}}
# 17           {{start date and age|1837}} in [[Paris]]
# 18                        {{start date and age|1962}}
# 19         {{start date and age|df|=|yes|1909|07|30}}
# 20             {{Start date and age|1987|6|3|df|=|y}}
# 21          {{start date and age|df|=|yes|1889|5|28}}
# 22                        {{start date and age|1975}}
# 23               {{start date and age|df|=|yes|1926}}
# 24            {{start date and age|1899|2|25|df|=|y}}
# 25            {{Start date and age|2005|5|11|df|=|y}}
# 26               {{start date and age|df|=|yes|1665}}
# 27          {{Start date and age|1973|2|15|df|=|yes}}
# 28  {{start date and age|1836|df|=|yes}} <br>(as [...
# 29           {{start date and age|1864|05|04|df|=|y}}
# 30                                                NaN
# 31                        {{start date and age|1987}}
# 32              {{Start date and age|1978}} in France
# 33                                                NaN
# 34           {{Start date and age|1924|03|28|df|=|y}}
# 35          {{start date and age|2007|6|27|df|=|yes}}
# 36  {{start date and age|1853}} (Compagnie Général...
#
#                                              founders  \
# 0   {{Unbulleted list|[[Gérard Pelisson]]|[[Paul D...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   {{ubl|Marcel Fournier|[[Denis Defforey]]|Jacqu...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20         {{ubl|Alain Chevalier|[[Henry Racamier]]}}
# 21  {{ubl|[[Édouard Michelin (born 1859)|Édouard M...
# 22                                                NaN
# 23                                                NaN
# 24  {{Plainlist|\n* [[Louis Renault (industrialist...
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28  {{Unbulleted list|[[Eugène Schneider]]<br>[[Ad...
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
#
#                                           hq_location  \
# 0                                    [[Tour Sequana]]
# 1                                                 NaN
# 2   {{Indented plainlist|\n* [[Leiden]], Netherlan...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                    [[Luxembourg City]], Luxembourg
# 17  24 [[Rue du Faubourg Saint-Honoré]] – 75008 Pa...
# 18                 40 rue de Sèvres, Paris 7e, France
# 19                                                NaN
# 20         22 [[Avenue Montaigne]]<br />Paris, France
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                  [[Paris]], France
# 28                                                NaN
# 29                                                NaN
# 30  [[Hoofddorp]], Netherlands (legal office) <br ...
# 31                                                NaN
# 32                           {{Coord|48.8754|2.3023}}
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
#
#                           hq_location_city hq_location_country  \
# 0                  [[Issy-les-Moulineaux]]              France
# 1                                      NaN                 NaN
# 2                                      NaN                 NaN
# 3                                      NaN                 NaN
# 4                                      NaN                 NaN
# 5                                      NaN                 NaN
# 6                                      NaN                 NaN
# 7                                      NaN                 NaN
# 8                                      NaN                 NaN
# 9                                      NaN                 NaN
# 10                                     NaN                 NaN
# 11                                     NaN                 NaN
# 12                                     NaN                 NaN
# 13                                     NaN                 NaN
# 14                                     NaN                 NaN
# 15  [[Paris]], France and [[Milan]], Italy                 NaN
# 16                                     NaN                 NaN
# 17                                     NaN                 NaN
# 18                                     NaN                 NaN
# 19                                     NaN                 NaN
# 20                                     NaN                 NaN
# 21                                     NaN                 NaN
# 22                                     NaN                 NaN
# 23                                     NaN                 NaN
# 24                                     NaN                 NaN
# 25                                     NaN                 NaN
# 26                                     NaN                 NaN
# 27                                     NaN                 NaN
# 28                                     NaN                 NaN
# 29                                     NaN                 NaN
# 30                                     NaN                 NaN
# 31                                     NaN                 NaN
# 32     <br /> [[Paris]], [[Île-de-France]]              France
# 33                                     NaN                 NaN
# 34                                     NaN                 NaN
# 35                                     NaN                 NaN
# 36                                     NaN                 NaN
#
#                                                  type  ...  \
# 0                           [[Public company|Public]]  ...
# 1              [[S.A. (corporation)|Société Anonyme]]  ...
# 2                           [[Public company|Public]]  ...
# 3                           [[Public company|Public]]  ...
# 4                           [[Public company|Public]]  ...
# 5                           [[Public company|Public]]  ...
# 6                           [[Public company|Public]]  ...
# 7              [[S.A. (corporation)|Société anonyme]]  ...
# 8                           [[Public company|Public]]  ...
# 9                                  [[Public company]]  ...
# 10                          [[Public company|Public]]  ...
# 11                                 [[Public company]]  ...
# 12                          [[Public company|Public]]  ...
# 13  [[Public company|Public]] ([[Societas Europaea]])  ...
# 14             [[S.A. (corporation)|Société Anonyme]]  ...
# 15                          [[Public company|Public]]  ...
# 16  [[Public company|Public]] (''[[Societas Europa...  ...
# 17  [[Public company|Public]] ([[S.A. (corporation...  ...
# 18                          [[Public company|Public]]  ...
# 19                          [[Public company|Public]]  ...
# 20                          [[Public company|Public]]  ...
# 21                          [[Public company|Public]]  ...
# 22  [[Public company|Public]] (''[[S.A. (corporati...  ...
# 23                          [[Public company|Public]]  ...
# 24                          [[Public company|Public]]  ...
# 25                          [[Public company|Public]]  ...
# 26             [[S.A. (corporation)|Société Anonyme]]  ...
# 27                          [[Public company|Public]]  ...
# 28                          [[Public company|Public]]  ...
# 29  {{lang|fr|[[S.A. (corporation)|Société Anonyme...  ...
# 30                          [[Public company|Public]]  ...
# 31                          [[Public company|Public]]  ...
# 32                          ''[[Societas Europaea]]''  ...
# 33                                                NaN  ...
# 34                          [[Public company|Public]]  ...
# 35  [[Public company|Public]] ([[Societas Europaea]])  ...
# 36                          [[Public company|Public]]  ...
#
#                                               caption            birth_date  \
# 0                                                 NaN                   NaN
# 1                                                 NaN                   NaN
# 2                                                 NaN                   NaN
# 3                                                 NaN                   NaN
# 4                                                 NaN                   NaN
# 5                                                 NaN                   NaN
# 6                                                 NaN                   NaN
# 7                                                 NaN                   NaN
# 8                                                 NaN                   NaN
# 9                                                 NaN                   NaN
# 10                                                NaN                   NaN
# 11                                                NaN                   NaN
# 12                                                NaN                   NaN
# 13                                                NaN                   NaN
# 14                                                NaN                   NaN
# 15                                                NaN                   NaN
# 16                                                NaN                   NaN
# 17                                                NaN                   NaN
# 18                                                NaN                   NaN
# 19                                                NaN                   NaN
# 20                                                NaN                   NaN
# 21                                                NaN                   NaN
# 22                                                NaN                   NaN
# 23                                                NaN                   NaN
# 24                                                NaN                   NaN
# 25                                                NaN                   NaN
# 26                                                NaN                   NaN
# 27                                                NaN                   NaN
# 28                                                NaN                   NaN
# 29                                                NaN                   NaN
# 30                                                NaN                   NaN
# 31                                                NaN                   NaN
# 32                                                NaN                   NaN
# 33  Posthumous portrait of Thales by Wilhelm Meyer...  {{circa}} 626/623 BC
# 34                                                NaN                   NaN
# 35                                                NaN                   NaN
# 36                                                NaN                   NaN
#
#                        birth_place                                death_date  \
# 0                              NaN                                       NaN
# 1                              NaN                                       NaN
# 2                              NaN                                       NaN
# 3                              NaN                                       NaN
# 4                              NaN                                       NaN
# 5                              NaN                                       NaN
# 6                              NaN                                       NaN
# 7                              NaN                                       NaN
# 8                              NaN                                       NaN
# 9                              NaN                                       NaN
# 10                             NaN                                       NaN
# 11                             NaN                                       NaN
# 12                             NaN                                       NaN
# 13                             NaN                                       NaN
# 14                             NaN                                       NaN
# 15                             NaN                                       NaN
# 16                             NaN                                       NaN
# 17                             NaN                                       NaN
# 18                             NaN                                       NaN
# 19                             NaN                                       NaN
# 20                             NaN                                       NaN
# 21                             NaN                                       NaN
# 22                             NaN                                       NaN
# 23                             NaN                                       NaN
# 24                             NaN                                       NaN
# 25                             NaN                                       NaN
# 26                             NaN                                       NaN
# 27                             NaN                                       NaN
# 28                             NaN                                       NaN
# 29                             NaN                                       NaN
# 30                             NaN                                       NaN
# 31                             NaN                                       NaN
# 32                             NaN                                       NaN
# 33  [[Miletus]], [[Ionian League]]  {{circa}} 548/545 BC (aged {{circa}} 78)
# 34                             NaN                                       NaN
# 35                             NaN                                       NaN
# 36                             NaN                                       NaN
#
#                             era                  region  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
# 5                           NaN                     NaN
# 6                           NaN                     NaN
# 7                           NaN                     NaN
# 8                           NaN                     NaN
# 9                           NaN                     NaN
# 10                          NaN                     NaN
# 11                          NaN                     NaN
# 12                          NaN                     NaN
# 13                          NaN                     NaN
# 14                          NaN                     NaN
# 15                          NaN                     NaN
# 16                          NaN                     NaN
# 17                          NaN                     NaN
# 18                          NaN                     NaN
# 19                          NaN                     NaN
# 20                          NaN                     NaN
# 21                          NaN                     NaN
# 22                          NaN                     NaN
# 23                          NaN                     NaN
# 24                          NaN                     NaN
# 25                          NaN                     NaN
# 26                          NaN                     NaN
# 27                          NaN                     NaN
# 28                          NaN                     NaN
# 29                          NaN                     NaN
# 30                          NaN                     NaN
# 31                          NaN                     NaN
# 32                          NaN                     NaN
# 33  [[Pre-Socratic philosophy]]  [[Western philosophy]]
# 34                          NaN                     NaN
# 35                          NaN                     NaN
# 36                          NaN                     NaN
#
#                                      school_tradition  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33  [[Ionian School (philosophy)|Ionian]] {{\}} [[...
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
#
#                                        main_interests  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33  {{hlist |[[Metaphysics]] |[[mathematics]] |[[a...
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
#
#                                         notable_ideas  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33  {{ublist|class|=|nowrap |[[Philosophy|Philosop...
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
#
#                                                 genre
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35  {{flat list|\n* [[Shopping mall|Shopping centr...
# 36                                                NaN
#
# [37 rows x 74 columns]

# %%
fetch_index_infoboxes("spla40")
# Out:
# 2025-11-29 18:15:16.956 | INFO     | __main__:fetch_index_infoboxes:70 - Index %s: found %d companies
# Fetching spla40 infoboxes:  42%|████▎     | 17/40 [00:29<00:35,  1.54s/it]API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 2025-11-29 18:15:46.812 | DEBUG    | __main__:fetch_index_infoboxes:89 - Error fetching %s: %s
# Fetching spla40 infoboxes:  62%|██████▎   | 25/40 [00:42<00:27,  1.85s/it]API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 2025-11-29 18:16:00.025 | DEBUG    | __main__:fetch_index_infoboxes:89 - Error fetching %s: %s
# Fetching spla40 infoboxes:  65%|██████▌   | 26/40 [00:43<00:21,  1.53s/it]API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 2025-11-29 18:16:00.792 | DEBUG    | __main__:fetch_index_infoboxes:89 - Error fetching %s: %s
# Fetching spla40 infoboxes:  80%|████████  | 32/40 [00:54<00:18,  2.29s/it]API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 2025-11-29 18:16:11.629 | DEBUG    | __main__:fetch_index_infoboxes:89 - Error fetching %s: %s
# Fetching spla40 infoboxes:  90%|█████████ | 36/40 [01:00<00:06,  1.64s/it]API error: {'code': 'invalidtitle', 'info': 'Bad title "StoneCo\xa0[pt]".', 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 2025-11-29 18:16:17.263 | DEBUG    | __main__:fetch_index_infoboxes:89 - Error fetching %s: %s
# Fetching spla40 infoboxes: 100%|██████████| 40/40 [01:05<00:00,  1.63s/it]
# 2025-11-29 18:16:22.311 | INFO     | __main__:fetch_index_infoboxes:98 - Index %s: successfully fetched %d infoboxes, failed %d
# 2025-11-29 18:16:22.312 | WARNING  | __main__:fetch_index_infoboxes:107 - Some companies failed (%d total): %s%s
# 2025-11-29 18:16:22.313 | INFO     | __main__:fetch_index_infoboxes:108 - Saved infobox database to %s
#                                         name  \
# 0                                 Ambev S.A.
# 1              América Móvil, S.A.B. de C.V.
# 2                        Banco Bradesco S.A.
# 3               Santander Chile Holding S.A.
# 4                             Banco de Chile
# 5                       Banco do Brasil S.A.
# 6                           Bancolombia S.A.
# 7                                   BRF S.A.
# 8                                     Motiva
# 9                       CEMEX S.A.B. de C.V.
# 10    Centros Comerciales Sudamericanos S.A.
# 11                            Credicorp Ltd.
# 12                            Ecopetrol S.A.
# 13                        Empresas CMPC S.A.
# 14                       Empresas Copec S.A.
# 15                        Enel Américas S.A.
# 16                               Gerdau S.A.
# 17  Grupo Financiero Banorte, S.A.B. de C.V.
# 18               Grupo México S.A.B. de C.V.
# 19                    Grupo Televisa, S.A.B.
# 20              Interconexión Eléctrica S.A.
# 21                        Itaú Unibanco S.A.
# 22                         Lojas Renner S.A.
# 23                       Magazine Luiza S.A.
# 24                   Natura &Co Holding S.A.
# 25                    PagSeguro Digital Ltd.
# 26    Petrobras<br/>Petróleo Brasileiro S.A.
# 27                            Falabella S.A.
# 28    Sociedad Química y Minera de Chile S.A
# 29               Southern Copper Corporation
# 30          Walmart de México S.A.B. de C.V.
# 31                                  WEG S.A.
#
#                                                  logo logo_size  \
# 0                                      Ambev logo.svg     225px
# 1                           Logo de América Móvil.svg     100px
# 2                                                 NaN     250px
# 3                        Banco Santander Logotipo.svg     200px
# 4                             Banco de Chile logo.svg       NaN
# 5                            Banco do Brasil Logo.svg       250
# 6                           Bancolombia S.A. logo.svg     250px
# 7                                   BRF S.A. logo.svg     150px
# 8                                          Motiva.svg       NaN
# 9                                 Cemex_logo_2023.png     250px
# 10                                  Cencosud-2014.svg       NaN
# 11                                                NaN       NaN
# 12                                 Ecopetrol logo.svg     200px
# 13                                      Logo-cmpc.svg       NaN
# 14                                                NaN       NaN
# 15                                Enel Group logo.svg       NaN
# 16                             Gerdau logo (2011).svg       NaN
# 17  Banorte (banking and financial services holdin...     250px
# 18                           Logo de Grupo México.svg       NaN
# 19                         Logo de Grupo Televisa.svg       NaN
# 20                   Logo Interconexión Eléctrica.png     200px
# 21                        Itaú Unibanco logo 2023.svg     150px
# 22                      Logotipo das Lojas Renner.svg       NaN
# 23                             Magalu - novo logo.png       NaN
# 24  [[File:Natura&Co.svg|frameless|class=skin-inve...       NaN
# 25                                   Logo PagBank.png       NaN
# 26                      Petrobras horizontal logo.svg     255px
# 27                       Grupo_Falabella_logotipo.png       NaN
# 28                 Sociedad Química y Minera logo.svg     150px
# 29               Southern Copper Corporation logo.svg       NaN
# 30            Walmart México y Centroamérica logo.svg     260px
# 31                           Weg logo blue vector.svg       150
#
#                                                  type  \
# 0            [[Public company|Public]] [[subsidiary]]
# 1                           [[Public company|Public]]
# 2            [[S.A. (corporation)|Sociedade Anônima]]
# 3             [[S.A. (corporation)|Sociedad Anónima]]
# 4             [[S.A. (corporation)|Sociedad Anónima]]
# 5            [[S.A. (corporation)|Sociedade Anônima]]
# 6             [[S.A. (corporation)|Sociedad Anónima]]
# 7                           [[Public company|Public]]
# 8            [[S.A. (corporation)|Sociedade Anônima]]
# 9   [[S.A. (corporation)|Sociedad Anónima Bursátil...
# 10                          [[Public company|Public]]
# 11                          [[Public company|Public]]
# 12            [[S.A. (corporation)|Sociedad Anónima]]
# 13  {{Lang|es|[[S.A. (corporation)|Sociedad Anónim...
# 14            [[S.A. (corporation)|Sociedad Anónima]]
# 15            [[S.A. (corporation)|Sociedad Anónima]]
# 16           [[S.A. (corporation)|Sociedade Anônima]]
# 17  [[S.A. (corporation)|Sociedad Anónima Bursátil...
# 18                          [[Public company|Public]]
# 19                          [[Public company|Public]]
# 20            [[S.A. (corporation)|Sociedad Anónima]]
# 21           [[S.A. (corporation)|Sociedade Anônima]]
# 22           [[S.A. (corporation)|Sociedade Anônima]]
# 23           [[S.A. (corporation)|Sociedade Anônima]]
# 24                          [[Public company|Public]]
# 25                         [[Public company |Public]]
# 26  [[Public company|Public]] [[S.A. (corporation)...
# 27                          [[Public company|Public]]
# 28            [[S.A. (corporation)|Sociedad Anónima]]
# 29                                 [[Public company]]
# 30           [[Public company|Public]] [[subsidiary]]
# 31           [[S.A. (corporation)|Sociedade Anônima]]
#
#                                             traded_as  \
# 0   {{Unbulleted list|B3 (stock exchange)|cvm|=|23...
# 1   {{BMV|AMX|6024}} <br /> {{New York Stock Excha...
# 2   {{B3 (stock exchange)|cvm|=|906|BBDC3|BBDC4}} ...
# 3   {{bcs|BSANTANDER}} <br /> {{New York Stock Exc...
# 4   {{BCS|CHILE}} <br/> {{NYSE|BCH}} <br/> {{BMAD|...
# 5   {{B3 (stock exchange)|cvm|=|1023|BBAS3}} <br>[...
# 6                 {{BVC|BCOLOMBIA}} <br> {{nyse|CIB}}
# 7   {{B3 (stock exchange)|cvm|=|16292|BRFS3}} <br>...
# 8   {{B3 (stock exchange)|cvm|=|18821|MOTV3}} <br>...
# 9   {{BMV|CEMEX|5203}} <br /> {{NYSE|CX}} <<br/> {...
# 10                                   {{BCS|CENCOSUD}}
# 11   [[Lima Stock Exchange|BVL]]:BAP<br> {{NYSE|BAP}}
# 12  {{BVC|ECOPETROL}} <br> {{NYSE|EC}} <br> {{FWB|...
# 13                                       {{BCS|CMPC}}
# 14                                      {{BCS|COPEC}}
# 15  {{Unbulleted list|BCS|ENELAM|\n[[Bolsa Electro...
# 16  {{B3 (stock exchange)|cvm|=|3980|GGBR3|GGBR4}}...
# 17  {{unbulleted list|BMV|GFNORTE|5433|BMAD|isin|=...
# 18                             {{BMV|GMEXICO B|6008}}
# 19      {{BMV|TLEVISA|5720}} <br /> {{nyse|TV}} (ADR)
# 20                   {{BVC|ISA}} <br> {{OTCQX|IESFY}}
# 21  {{B3 (stock exchange)|cvm|=|19348|ITUB3|ITUB4}...
# 22  {{B3 (stock exchange)|cvm|=|8133|LREN3}} <br>[...
# 23                                                NaN
# 24  {{B3 (stock exchange)|cvm|=|24783|NTCO3}} <br ...
# 25                                      {{NYSE|PAGS}}
# 26  {{unbulleted list|\n| |B3 (stock exchange)|cvm...
# 27                                  {{bcs|FALABELLA}}
# 28  {{ubl|BCS|SQM-A|BCS|SQM-B|NYSE|SQM}} {{BCS|SQM...
# 29  {{BVL|id|=|75850|SCCO}} <br> {{NYSE|SCCO}} <br...
# 30                              {{BMV|WALMEX V|5214}}
# 31  {{B3 (stock exchange)|cvm|=|5410|WEGE3}} <br>[...
#
#                                            foundation hq_location_city  \
# 0                         {{Start date and age|1999}}    [[São Paulo]]
# 1          {{start date and age|2000|09|25|df|=|yes}}              NaN
# 2   {{start date and age|1943|03|10}} in [[Marília...       [[Osasco]]
# 3                                                1978              NaN
# 4                                        October 1893              NaN
# 5   [[Rio de Janeiro]], [[Captaincy of Rio de Jane...              NaN
# 6   {{Start date and age|df|=|yes|1875|01|29}} (as...              NaN
# 7              {{start date and age|August 18, 1934}}              NaN
# 8                                                1999              NaN
# 9                {{start date and age|1906|df|=|yes}}              NaN
# 10                        {{start date and age|1960}}              NaN
# 11                                               1995              NaN
# 12  {{Start date and age|1921}} <br/>(Tropical Oil...              NaN
# 13            {{start date and age|1920|3|12|df|=|y}}              NaN
# 14                                               1934              NaN
# 15                                               1889              NaN
# 16                  {{start date and age|1901|01|16}}              NaN
# 17               {{start date and age|df|=|yes|1899}}              NaN
# 18  {{start date and age|df|=|yes|1978}} {{citatio...              NaN
# 19           {{start date and age|1973|01|08|df|=|y}}              NaN
# 20                                               1967              NaN
# 21    {{start date and age|2008|11|04|df|=|y|br|=|y}}              NaN
# 22                                               1912              NaN
# 23                                                NaN              NaN
# 24                        {{start date and age|1969}}              NaN
# 25                                                NaN    [[São Paulo]]
# 26              {{start date and age|3 October 1953}}              NaN
# 27                        {{start date and age|1889}}              NaN
# 28                   {{Start date and age|1968|6|11}}              NaN
# 29                        {{start date and age|1952}}              NaN
# 30               {{start date and age|df|=|yes|1986}}              NaN
# 31           {{start date and age|16 September 1961}}              NaN
#
#                                   hq_location_country  \
# 0                                              Brazil
# 1                                                 NaN
# 2                                          [[Brazil]]
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25  [[Brazil]] (operational); [[Grand Cayman]], [[...
# 26                                         [[Brazil]]
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
#
#                                           area_served  \
# 0           [[Brazil]], [[Latin America]], [[Canada]]
# 1                                                 NaN
# 2                                           Worldwide
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   [[Colombia]], [[Cayman Islands]], [[El Salvado...
# 7                                           Worldwide
# 8                                                 NaN
# 9                                           Worldwide
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                             Mexico
# 18                                                NaN
# 19                                          Worldwide
# 20  [[Colombia]], [[Peru]], [[Brazil]], [[Bolivia]...
# 21                                          Worldwide
# 22                                                NaN
# 23                                                NaN
# 24                                          Worldwide
# 25                                                NaN
# 26                                          Worldwide
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                          Worldwide
#
#                                            key_people  ...      trade_name  \
# 0            Jean Jereissati ([[chairman]] & [[CEO]])  ...             NaN
# 1   [[Carlos Slim Helú]] ([[Chairman|chairman emer...  ...             NaN
# 2   Luiz Carlos Trabuco Cappi <small>([[Chairman]]...  ...             NaN
# 3      [[Mauricio Larraín]], <small>([[CEO]])</small>  ...             NaN
# 4   {{unbulleted list|[[Pablo Granifo Lavín]] <sma...  ...             NaN
# 5   [[Tarciana Medeiros]] ([[Chairperson|Chairwoma...  ...             NaN
# 6   Juan Carlos Mora Uribe, ([[President (corporat...  ...             NaN
# 7   Lorival Nogueira Luz Jr. (CEO) <Br> [[Pedro Pa...  ...             NaN
# 8     Miguel Setas  ([[Chief executive officer|CEO]])  ...             NaN
# 9   Rogelio Zambrano Lozano<br> {{small|(Executive...  ...             NaN
# 10            [[Horst Paulmann|Horst Paulmann Kemna]]  ...             NaN
# 11  Luis Romero Belismelis (chairman)<br />Gianfra...  ...             NaN
# 12              Ricardo Roa, ([[Chairman]] & [[CEO]])  ...             NaN
# 13  [[Luis Felipe Gazitua]], <small>([[Chairman]])...  ...             NaN
# 14  Roberto Angelini Rossi, <small>([[Chairman]])<...  ...             NaN
# 15                                                NaN  ...             NaN
# 16  {{nowrap|Guilherme Chagas Gerdau Johannpeter, ...  ...             NaN
# 17  [[Carlos Hank González (businessman, born 1971...  ...             NaN
# 18  [[Germán Larrea Mota-Velasco]]  <small>([[Chai...  ...             NaN
# 19  (co-CEOs)<br/>[[Alfonso de Angoitia]]<br>[[Ber...  ...  Grupo Televisa
# 20                    Jorge Andrés Carrillo ([[CEO]])  ...             NaN
# 21  {{unbulleted list|Milton Maluhy Filho ([[Chief...  ...             NaN
# 22  José Galló, <small>([[Chairman]])</small><br> ...  ...             NaN
# 23  CEO: [[Frederico Trajano]] <br/> Chair: [[Luiz...  ...             NaN
# 24  Roberto Marques ([[Chairman]])<br />João Paulo...  ...             NaN
# 25                                                NaN  ...             NaN
# 26  {{Unbulleted list\n| [[Magda Chambriard]] ([[C...  ...             NaN
# 27  Carlo Solari Donaggio ([[chairman]])<br />Alej...  ...             NaN
# 28      Ricardo Ramos (CEO) <br>[[Julio Ponce Lerou]]  ...             NaN
# 29          {{nowrap|[[Oscar González Rocha]] (CEO)}}  ...             NaN
# 30  Guilherme Loureiro ([[Chief executive officer|...  ...             NaN
# 31  Décio da Silva ([[Chairman]]) <br>Alberto Kuba...  ...             NaN
#
#                                          predecessors  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  [[Telesistema Mexicano]]<br />[[Televisión Ind...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
#
#                                                brands  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  {{Plainlist|\n* [[Las Estrellas]]\n* [[Canal 5...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
#
#                                               members      net_income_year  \
# 0                                                 NaN                  NaN
# 1                                                 NaN                  NaN
# 2                                                 NaN                  NaN
# 3                                                 NaN                  NaN
# 4                                                 NaN                  NaN
# 5                                                 NaN                  NaN
# 6                                                 NaN                  NaN
# 7                                                 NaN                  NaN
# 8                                                 NaN                  NaN
# 9                                                 NaN                  NaN
# 10                                                NaN                  NaN
# 11                                                NaN                  NaN
# 12                                                NaN                  NaN
# 13                                                NaN                  NaN
# 14                                                NaN                  NaN
# 15                                                NaN                  NaN
# 16                                                NaN                  NaN
# 17                                                NaN                  NaN
# 18                                                NaN                  NaN
# 19  [[Organización de Telecomunicaciones de Iberoa...                  NaN
# 20                                                NaN                 2023
# 21                                                NaN                  NaN
# 22                                                NaN                  NaN
# 23                                                NaN                  NaN
# 24                                                NaN                  NaN
# 25                                                NaN                 2017
# 26                                                NaN  <small>2022</small>
# 27                                                NaN                  NaN
# 28                                                NaN                  NaN
# 29                                                NaN                  NaN
# 30                                                NaN                  NaN
# 31                                                NaN                  NaN
#
#                                               website  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                 {{URL|https://www.naturaeco.com/}}
# 25                    {{URL|https://pagbank.com.br/}}
# 26  {{URL|https://petrobras.com.br/en/|petrobras.c...
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
#
#                          founded         hq_location  \
# 0                            NaN                 NaN
# 1                            NaN                 NaN
# 2                            NaN                 NaN
# 3                            NaN                 NaN
# 4                            NaN                 NaN
# 5                            NaN                 NaN
# 6                            NaN                 NaN
# 7                            NaN                 NaN
# 8                            NaN                 NaN
# 9                            NaN                 NaN
# 10                           NaN                 NaN
# 11                           NaN                 NaN
# 12                           NaN                 NaN
# 13                           NaN                 NaN
# 14                           NaN                 NaN
# 15                           NaN                 NaN
# 16                           NaN                 NaN
# 17                           NaN                 NaN
# 18                           NaN                 NaN
# 19                           NaN                 NaN
# 20                           NaN                 NaN
# 21                           NaN                 NaN
# 22                           NaN                 NaN
# 23                           NaN                 NaN
# 24                           NaN                 NaN
# 25  {{start date and age |2006}}                 NaN
# 26                           NaN  [[Rio de Janeiro]]
# 27                           NaN                 NaN
# 28                           NaN                 NaN
# 29                           NaN                 NaN
# 30                           NaN                 NaN
# 31                           NaN                 NaN
#
#                                            production num_locations_year
# 0                                                 NaN                NaN
# 1                                                 NaN                NaN
# 2                                                 NaN                NaN
# 3                                                 NaN                NaN
# 4                                                 NaN                NaN
# 5                                                 NaN                NaN
# 6                                                 NaN                NaN
# 7                                                 NaN                NaN
# 8                                                 NaN                NaN
# 9                                                 NaN                NaN
# 10                                                NaN                NaN
# 11                                                NaN                NaN
# 12                                                NaN                NaN
# 13                                                NaN                NaN
# 14                                                NaN                NaN
# 15                                                NaN                NaN
# 16                                                NaN                NaN
# 17                                                NaN                NaN
# 18                                                NaN                NaN
# 19                                                NaN                NaN
# 20                                                NaN                NaN
# 21                                                NaN                NaN
# 22                                                NaN                NaN
# 23                                                NaN                NaN
# 24                                                NaN                NaN
# 25                                                NaN                NaN
# 26  {{convert|3.40|e6BOE|lk|=|in}} per day <small>...                NaN
# 27                                                NaN                NaN
# 28                                                NaN                NaN
# 29                                                NaN                NaN
# 30                                                NaN               2025
# 31                                                NaN                NaN
#
# [32 rows x 51 columns]

# %%
fetch_index_infoboxes("dax")
# Out:
# 2025-11-29 18:16:22.351 | INFO     | __main__:fetch_index_infoboxes:70 - Index %s: found %d companies
# Fetching dax infoboxes: 100%|██████████| 41/41 [01:34<00:00,  2.32s/it]
# 2025-11-29 18:17:57.325 | INFO     | __main__:fetch_index_infoboxes:98 - Index %s: successfully fetched %d infoboxes, failed %d
# 2025-11-29 18:17:57.325 | WARNING  | __main__:fetch_index_infoboxes:107 - Some companies failed (%d total): %s%s
# 2025-11-29 18:17:57.326 | INFO     | __main__:fetch_index_infoboxes:108 - Saved infobox database to %s
#                                            name  \
# 0                                     Adidas AG
# 1                                     Airbus SE
# 2                                       Allianz
# 3                                       BASF SE
# 4                                      Bayer AG
# 5                                 Beiersdorf AG
# 6   Bayerische Motoren Werke Aktiengesellschaft
# 7                                   Brenntag SE
# 8                                Commerzbank AG
# 9                                   Covestro AG
# 10                     Daimler Truck Holding AG
# 11                             Deutsche Bank AG
# 12                            Deutsche Börse AG
# 13               Post & Parcel Germany division
# 14                          Deutsche Telekom AG
# 15                                      E.ON SE
# 16         Fresenius Medical Care AG & Co. KGaA
# 17                             Hannover Rück SE
# 18                         Heidelberg Materials
# 19                         Henkel AG & Co. KGaA
# 20                     Infineon Technologies AG
# 21                       Mercedes-Benz Group AG
# 22                          MTU Aero Engines AG
# 23                              Munich Re Group
# 24                  Dr. Ing. h.c. F. Porsche AG
# 25                 Porsche Automobil Holding SE
# 26                                  QIAGEN N.V.
# 27                               Rheinmetall AG
# 28                                       RWE AG
# 29                                       SAP SE
# 30                                   Siemens AG
# 31                            Siemens Energy AG
# 32                      Siemens Healthineers AG
# 33                                   Symrise AG
# 34                                Volkswagen AG
# 35                                   Vonovia SE
# 36                                   Zalando SE
#
#                                           former_name  \
# 0            Gebrüder Dassler Schuhfabrik (1924–1949)
# 1   {{Indented plainlist|\n* '''Parent company:'''...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  {{ubl\n|Daimler-Benz AG (1926–1998)\n|DaimlerC...
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25  {{plainlist|\n* Dr. Ing. h.c. F. Porsche GmbH ...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                 Deutsche Annington
# 36                                                NaN
#
#                                                  logo logo_size  \
# 0                                Adidas 2022 logo.svg       200
# 1        Airbus Logo 2017.svg {{!}} class=skin-invert     180px
# 2                                         Allianz.svg       NaN
# 3                                    BASF-Logo bw.svg     205px
# 4                                      Logo Bayer.svg     160px
# 5   Beiersdorf Logo.svg {{!}} class=skin-invert-image     250px
# 6       BMW logo (white + grey background square).svg       NaN
# 7                              Brenntag Logo 2022.svg     250px
# 8                              Commerzbank (2009).svg       NaN
# 9                                   Covestro Logo.svg     150px
# 10                             Daimler_Truck_Logo.svg     250px
# 11  [[File:Deutsche Bank logo.svg|frameless|220px|...       NaN
# 12                                 Deutsche Börse.svg     200px
# 13                        Logo Deutsche Post 2019.svg     220px
# 14                          Deutsche Telekom 2022.svg      80px
# 15                                      Logo E.ON.svg       NaN
# 16                         Fresenius Medical Care.svg     235px
# 17                          Hannover RE Logo 2024.svg     230px
# 18                                                NaN     250px
# 19                                    Henkel-Logo.svg     200px
# 20                                  Infineon-Logo.svg       NaN
# 21  [[File:Mercedes-Benz Group black.svg|frameless...     250px
# 22                          MTU Aero Engines Logo.svg       NaN
# 23                                      Munich Re.svg       NaN
# 24                              Porsche Logo 2024.png       100
# 25  [[File:Porsche_SE_Logo.svg|frameless|class=ski...       NaN
# 26                         [[Image:Qiagen.svg|130px]]       NaN
# 27                          Rheinmetall Logo 2021.svg     220px
# 28                                  RWE Logo 2020.svg     125px
# 29                                  SAP 2011 logo.svg       NaN
# 30                                Siemens AG logo.svg       NaN
# 31                            Siemens Energy logo.svg       NaN
# 32                                                NaN       NaN
# 33                                   Symrise_logo.svg     250px
# 34                     Volkswagen Group Logo 2023.svg       250
# 35                                   Vonovia Logo.svg       NaN
# 36                              Zalando Logo 2024.svg     200px
#
#                                          logo_caption  \
# 0                                Main logo since 2022
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5           Beiersdorf's logo used since January 2014
# 6                            Official logo since 2020
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  Logo used since 2019. Before 2019, the {{lang|...
# 14                           Official logo since 2022
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
#
#                                                 image image_size  \
# 0                  Herzogenaurach - Adidas - 2016.jpg        250
# 1            Airbus Lagardère - Aéroconstellation.jpg      250px
# 2              Wzwz_schwabing_26_allianz_building.JPG        NaN
# 3                                                 NaN        NaN
# 4            Leverkusen Kaiser-Wilhelm-Allee 0004.jpg        NaN
# 5               Beiersdorf Headquarters Hamburg 1.jpg      250px
# 6           4 cilindros de BMW, Múnich, Alemania1.jpg        NaN
# 7                                                 NaN        NaN
# 8          Frankfurt_Commerzbank_vom_Schaumainkai.jpg        NaN
# 9                                                 NaN        NaN
# 10                Stuttgart_Daimler_Untertuerkeim.jpg      250px
# 11                     Deutsche Bank Taunusanlage.jpg        NaN
# 12                 Deutsche-boerse-parkett-ffm001.jpg      260px
# 13                                                NaN        NaN
# 14                 Deutsche Telekom Zentrale Bonn.jpg      250px
# 15                     EON-Ruhrgas-Zentrale Essen.jpg        NaN
# 16                                                NaN        NaN
# 17                               HannRueck 0098 m.jpg        NaN
# 18                                                NaN        NaN
# 19           Henkel Düsseldorf HolthausenP8190172.JPG        NaN
# 20                               Campeon Luftbild.JPG        NaN
# 21           Stuttgart-Untertuerkheim-DC-Zentrale.jpg      250px
# 22                         MTU Headquaters Munich.jpg        NaN
# 23                                                NaN        NaN
# 24  Porsche headquarter Stuttgart-Zuffenhausen Wer...        NaN
# 25  Porsche headquarter Stuttgart-Zuffenhausen Wer...      250px
# 26                                                NaN        NaN
# 27                Rheinmetall Zentrale Düsseldorf.jpg        NaN
# 28                                                NaN        NaN
# 29                                                NaN        NaN
# 30       The Wings, Siemens HQ Munich, April 2017.jpg        NaN
# 31                                                NaN        NaN
# 32                                                NaN        NaN
# 33                                                NaN        NaN
# 34                           Wolfsburg VWHochhaus.jpg        250
# 35                                Vonovia-8665-HD.jpg        NaN
# 36                            Zalando Headquarter.jpg      250px
#
#                                         image_caption  \
# 0   Current factory outlet in Herzogenaurach, Germ...
# 1   Lagardère production plant in [[Blagnac]], France
# 2                              Headquarters in Munich
# 3                                                 NaN
# 4                          Headquarters in Leverkusen
# 5                Headquarters in [[Hamburg]], Germany
# 6             [[BMW Headquarters]] in Munich, Germany
# 7                                                 NaN
# 8   [[Commerzbank Tower]], the headquarters of Com...
# 9                                                 NaN
# 10                        Daimler Truck AG facilities
# 11  [[Deutsche Bank Twin Towers]] in [[Frankfurt]]...
# 12  {{Lang|de|Deutsche Börse|italic|=|no}} trading...
# 13                                                NaN
# 14                               Headquarters in Bonn
# 15  E.ON's corporate headquarters in [[Essen]], Ge...
# 16                                                NaN
# 17                   Company headquarters in Hannover
# 18                                                NaN
# 19   Henkel's headquarters in [[Düsseldorf]], Germany
# 20     Infineon's headquarters "Campeon" in Neubiberg
# 21  Central headquarters in Mercedes-Benz complex ...
# 22        MTU Aero Engines Headquarters in [[Munich]]
# 23                                                NaN
# 24                          Headquarters in Stuttgart
# 25     Porsche headquarters in [[Stuttgart]], Germany
# 26                                                NaN
# 27            Rheinmetall's head office in Düsseldorf
# 28                                                NaN
# 29                                                NaN
# 30                         Headquarters in [[Munich]]
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34             Headquarters in [[Wolfsburg]], Germany
# 35                            Headquarters of Vonovia
# 36                             Headquarters in Berlin
#
#                                                  type  \
# 0                           [[Public company|Public]]
# 1                           [[Public company|Public]]
# 2   [[Public company|Public]] (''[[societas Europa...
# 3                           [[Public company|Public]]
# 4                           [[Public company|Public]]
# 5   [[Public company|Public]] ([[Aktiengesellschaf...
# 6                           [[Public company|Public]]
# 7   [[Public company|Public]] (''[[Societas Europa...
# 8                           [[Public company|Public]]
# 9                          ''[[Aktiengesellschaft]]''
# 10                          [[public company|Public]]
# 11                          [[Public company|Public]]
# 12  [[Public company|Public]] ( {{Lang|de|[[Aktien...
# 13                   [[Division (business)|Division]]
# 14                          [[Public company|Public]]
# 15                          [[Public company|Public]]
# 16  [[KGaA]] with [[Aktiengesellschaft]] as partne...
# 17  [[Public company|Public]] (''[[Societas Europa...
# 18                             [[Aktiengesellschaft]]
# 19                          [[Public company|Public]]
# 20                          [[Public company|Public]]
# 21                          [[Public company|Public]]
# 22                             [[Aktiengesellschaft]]
# 23                         ''[[Aktiengesellschaft]]''
# 24  [[Public company|Public]] (''[[Aktiengesellsch...
# 25  [[Public company|Public]] (''[[Societas Europa...
# 26  [[Public company|Public]] (''[[Naamloze vennoo...
# 27  [[Public company|Public]] ( {{lang|de|[[Aktien...
# 28                             [[Aktiengesellschaft]]
# 29                          [[Public company|Public]]
# 30                          [[Public company|Public]]
# 31                         ''[[Aktiengesellschaft]]''
# 32  [[Public company|Public]] (''[[Aktiengesellsch...
# 33                             [[Aktiengesellschaft]]
# 34                          [[Public company|Public]]
# 35  [[Public company|Public]] (''[[societas Europa...
# 36  [[Public company|Public]] (''[[Societas Europa...
#
#                                             traded_as  ...  \
# 0   {{FWB|ADS|isin|=|DE000A1EWWW0}} <br />[[DAX|DA...  ...
# 1   {{Plainlist|\n* |BMAD|isin|=|NL0000235190|AIR|...  ...
# 2       {{ubl|FWB|ALV|[[DAX]] component}} {{FWB|ALV}}  ...
# 3   {{ubl|FWB|BAS|isin|=|DE000BASF111|[[DAX]] comp...  ...
# 4   {{ubl|class|=|nowrap|FWB|BAYN|[[DAX]] componen...  ...
# 5   {{Unbulleted list | |FWB|BEI| | [[DAX]] compon...  ...
# 6   {{unbulleted list| |FWB|BMW| |[[DAX]] componen...  ...
# 7   {{Unbulleted list |FWB|BNR| |FWB|BNRA| ([[Amer...  ...
# 8                             {{FWB|CBK}} <br>[[DAX]]  ...
# 9           {{plainlist|\n* |FWB|1COV|}} {{FWB|1COV}}  ...
# 10  {{fwb|DTG|isin|=|DE000DTR0CK8}} <br>[[DAX]] co...  ...
# 11  {{plainlist|\n*|FWB|DBK|\n*|NYSE|DB|\n*[[DAX]]...  ...
# 12      {{ubl|FWB|DB1|[[DAX]] component}} {{FWB|DB1}}  ...
# 13                                                NaN  ...
# 14            {{FWB|DTE}} <br />[[DAX|DAX Component]]  ...
# 15           {{FWB|EOAN}} <br />[[DAX|DAX Component]]  ...
# 16  {{FWB|FME}} <br /> {{FWB|FMEA}} ([[American De...  ...
# 17  {{FWB|HNR1}} <br/> {{FWB|HNRB}} ([[American De...  ...
# 18            {{FWB|HEI}} <br />[[DAX|DAX component]]  ...
# 19  {{FWB|HEN}} ([[Common shares]])<br /> {{FWB|HE...  ...
# 20  {{Ubl|FWB|IFX|isin|=|DE0006231004|[[DAX]] comp...  ...
# 21  {{Unbulleted list|FWB|MBG|[[DAX]] component}} ...  ...
# 22            {{FWB|MTX}} <br />[[DAX|DAX Component]]  ...
# 23           {{FWB|MUV2}} <br />[[DAX|DAX Component]]  ...
# 24  {{FWB|P911|isin|=|DE000PAG9113}} <br />[[DAX]]...  ...
# 25                 {{fwb|PAH3}} <br>[[DAX]] component  ...
# 26  {{Unbulleted list|NYSE|QGEN|FWB|QIA|[[Russell ...  ...
# 27  {{Unbulleted list\n  | |FWB|RHM|\n  | |FWB|RHM...  ...
# 28  {{FWB|RWE}} <br /> {{FWB|RWEA}} ([[American de...  ...
# 29  {{Unbulleted list|FWB|SAP|FWB|SAPA| ([[America...  ...
# 30      {{ubl|FWB|SIE|[[DAX]] component}} {{FWB|SIE}}  ...
# 31             {{FWB|ENR}} <br/>[[DAX|DAX Component]]  ...
# 32                 {{FWB|SHL}} <br/>[[DAX]] component  ...
# 33  {{FWB|SY1}} <br/> {{FWB|SY1U}} <br/>[[DAX]] co...  ...
# 34  {{FWB|VOW|isin|=|DE0007664005}} , {{FWB|VOW3|i...  ...
# 35            {{FWB|VNA}} <br />[[DAX|DAX Component]]  ...
# 36  {{Unbulleted list |FWB|ZAL| |[[DAX]] component...  ...
#
#                                               website         parent  \
# 0                                                 NaN            NaN
# 1                                                 NaN            NaN
# 2                                                 NaN            NaN
# 3                                                 NaN            NaN
# 4                                                 NaN            NaN
# 5                                                 NaN            NaN
# 6                                                 NaN            NaN
# 7                                                 NaN            NaN
# 8                                    {{Official URL}}            NaN
# 9                                                 NaN            NaN
# 10                                                NaN            NaN
# 11                                                NaN            NaN
# 12  {{URL|https://deutsche-boerse.com/dbg-en/|deut...            NaN
# 13                                                NaN  [[DHL Group]]
# 14                                                NaN            NaN
# 15                                                NaN            NaN
# 16                                                NaN            NaN
# 17                                                NaN            NaN
# 18                                                NaN            NaN
# 19                                                NaN            NaN
# 20                                                NaN            NaN
# 21                                                NaN            NaN
# 22                                                NaN            NaN
# 23                                                NaN            NaN
# 24                                                NaN            NaN
# 25                                                NaN            NaN
# 26                                 {{URL|qiagen.com}}            NaN
# 27                                                NaN            NaN
# 28                                                NaN            NaN
# 29                                                NaN            NaN
# 30                                                NaN            NaN
# 31                                                NaN            NaN
# 32                                                NaN            NaN
# 33                                                NaN            NaN
# 34                                                NaN            NaN
# 35                                 {{URL|vonovia.de}}            NaN
# 36            {{URL|https://zalando.com|zalando.com}}            NaN
#
#      logo_class                                             module  \
# 0           NaN                                                NaN
# 1           NaN                                                NaN
# 2           NaN                                                NaN
# 3           NaN                                                NaN
# 4           NaN                                                NaN
# 5           NaN                                                NaN
# 6           NaN                                                NaN
# 7           NaN                                                NaN
# 8           NaN                                                NaN
# 9           NaN                                                NaN
# 10          NaN                                                NaN
# 11          NaN                                                NaN
# 12          NaN                                                NaN
# 13          NaN                                                NaN
# 14  skin-invert  {{Infobox NSP\n| child |=| yes\n| asn |=| 3320...
# 15          NaN                                                NaN
# 16          NaN                                                NaN
# 17          NaN                                                NaN
# 18          NaN                                                NaN
# 19          NaN                                                NaN
# 20          NaN                                                NaN
# 21          NaN                                                NaN
# 22          NaN                                                NaN
# 23          NaN                                                NaN
# 24          NaN                                                NaN
# 25          NaN                                                NaN
# 26          NaN                                                NaN
# 27          NaN                                                NaN
# 28          NaN                                                NaN
# 29          NaN                                                NaN
# 30          NaN                                                NaN
# 31          NaN                                                NaN
# 32          NaN                                                NaN
# 33          NaN                                                NaN
# 34          NaN                                                NaN
# 35          NaN                                                NaN
# 36          NaN                                                NaN
#
#            former_names                         image_alt logo_upright  \
# 0                   NaN                               NaN          NaN
# 1                   NaN                               NaN          NaN
# 2                   NaN                               NaN          NaN
# 3                   NaN                               NaN          NaN
# 4                   NaN                               NaN          NaN
# 5                   NaN                               NaN          NaN
# 6                   NaN                               NaN          NaN
# 7                   NaN                               NaN          NaN
# 8                   NaN                               NaN          NaN
# 9                   NaN                               NaN          NaN
# 10                  NaN                               NaN          NaN
# 11                  NaN                               NaN          NaN
# 12                  NaN                               NaN          NaN
# 13                  NaN                               NaN          NaN
# 14                  NaN                               NaN          NaN
# 15  E.ON AG (2000-2012)                               NaN          NaN
# 16                  NaN                               NaN          NaN
# 17                  NaN  Company headquarters in Hannover          NaN
# 18                  NaN                               NaN          NaN
# 19                  NaN                               NaN          NaN
# 20                  NaN                               NaN          1.0
# 21                  NaN                               NaN          NaN
# 22                  NaN                               NaN          NaN
# 23                  NaN                               NaN          NaN
# 24                  NaN                               NaN          NaN
# 25                  NaN                               NaN          NaN
# 26                  NaN                               NaN          NaN
# 27                  NaN                               NaN          NaN
# 28                  NaN                               NaN          NaN
# 29                  NaN                               NaN          NaN
# 30                  NaN                               NaN          1.1
# 31                  NaN                               NaN          NaN
# 32                  NaN                               NaN          NaN
# 33                  NaN                               NaN          NaN
# 34                  NaN                               NaN          NaN
# 35                  NaN                               NaN          NaN
# 36                  NaN                               NaN          NaN
#
#     trade_name                                        native_name  \
# 0          NaN                                                NaN
# 1          NaN                                                NaN
# 2          NaN                                                NaN
# 3          NaN                                                NaN
# 4          NaN                                                NaN
# 5          NaN                                                NaN
# 6          NaN                                                NaN
# 7          NaN                                                NaN
# 8          NaN                                                NaN
# 9          NaN                                                NaN
# 10         NaN                                                NaN
# 11         NaN                                                NaN
# 12         NaN                                                NaN
# 13         NaN                                                NaN
# 14         NaN                                                NaN
# 15         NaN                                                NaN
# 16         NaN                                                NaN
# 17         NaN                                                NaN
# 18         NaN                                                NaN
# 19         NaN                                                NaN
# 20         NaN                                                NaN
# 21         NaN                                                NaN
# 22         NaN                                                NaN
# 23   Munich Re  ''Münchener Rückversicherungs-Gesellschaft Akt...
# 24         NaN                                                NaN
# 25  Porsche SE                                                NaN
# 26         NaN                                                NaN
# 27         NaN                                                NaN
# 28         NaN                                                NaN
# 29         NaN                                                NaN
# 30         NaN                                                NaN
# 31         NaN                                                NaN
# 32         NaN                                                NaN
# 33         NaN                                                NaN
# 34         NaN                                                NaN
# 35         NaN                                                NaN
# 36         NaN                                                NaN
#
#                                          areas_served
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35  {{Unbulleted list|Germany (84%)|Sweden (11%)|A...
# 36                                                NaN
#
# [37 rows x 68 columns]

# %%
def load_and_analyze_infobox_data(
    databases_dir: Path | str = Path("./data/databases")
) -> Dict[str, pd.DataFrame]:
    """
    Load all *_infoboxes.csv files from `databases_dir`, print basic stats,
    and return a dictionary of DataFrames keyed by index name.
    """
    databases_dir = Path(databases_dir)
    csv_files = sorted(databases_dir.glob("*_infoboxes.csv"))

    infobox_data: Dict[str, pd.DataFrame] = {}

    if not csv_files:
        print(f"⚠️ No *_infoboxes.csv files found in {databases_dir.resolve()}")
        return infobox_data

    print("📂 Loading infobox CSVs from:", databases_dir.resolve())

    for csv_path in csv_files:
        index_name = csv_path.stem.replace("_infoboxes", "")

        df = pd.read_csv(csv_path)
        infobox_data[index_name] = df

        print("\n" + "=" * 60)
        print(f" INDEX: {index_name.upper()}")
        print("=" * 60)
        print(f"- File: {csv_path.name}")
        print(f"- Shape: {len(df)} rows × {len(df.columns)} columns")
        print(f"- Example columns:")

        # Affiche les 10 premières colonnes max, plus un message si plus
        max_cols_preview = 10
        preview_cols = list(df.columns[:max_cols_preview])
        for col in preview_cols:
            print(f"  • {col}")

        remaining = len(df.columns) - len(preview_cols)
        if remaining > 0:
            print(f"  … and {remaining} more columns")

    print("\n✅ Data loaded into 'infobox_data' with indexes:")
    print("   ", ", ".join(sorted(infobox_data.keys())))

    return infobox_data


# Exécution
infobox_data = load_and_analyze_infobox_data()
# Out:
# 📂 Loading infobox CSVs from: /content/data/databases
#
# ============================================================
#  INDEX: CAC40
# ============================================================
# - File: cac40_infoboxes.csv
# - Shape: 37 rows × 74 columns
# - Example columns:
#   • name
#   • logo
#   • logo_alt
#   • logo_size
#   • foundation
#   • founders
#   • hq_location
#   • hq_location_city
#   • hq_location_country
#   • type
#   … and 64 more columns
#
# ============================================================
#  INDEX: DAX
# ============================================================
# - File: dax_infoboxes.csv
# - Shape: 37 rows × 68 columns
# - Example columns:
#   • name
#   • former_name
#   • logo
#   • logo_size
#   • logo_caption
#   • image
#   • image_size
#   • image_caption
#   • type
#   • traded_as
#   … and 58 more columns
#
# ============================================================
#  INDEX: NASDAQ100
# ============================================================
# - File: nasdaq100_infoboxes.csv
# - Shape: 98 rows × 70 columns
# - Example columns:
#   • name
#   • logo
#   • image
#   • image_upright
#   • image_caption
#   • trading_name
#   • former_name
#   • type
#   • traded_as
#   • industry
#   … and 60 more columns
#
# ============================================================
#  INDEX: SP500
# ============================================================
# - File: sp500_infoboxes.csv
# - Shape: 474 rows × 120 columns
# - Example columns:
#   • name
#   • logo
#   • logo_size
#   • image
#   • image_size
#   • image_caption
#   • former_name
#   • type
#   • traded_as
#   • ISIN
#   … and 110 more columns
#
# ============================================================
#  INDEX: SPLA40
# ============================================================
# - File: spla40_infoboxes.csv
# - Shape: 32 rows × 51 columns
# - Example columns:
#   • name
#   • logo
#   • logo_size
#   • type
#   • traded_as
#   • foundation
#   • hq_location_city
#   • hq_location_country
#   • area_served
#   • key_people
#   … and 41 more columns
#
# ✅ Data loaded into 'infobox_data' with indexes:
#     cac40, dax, nasdaq100, sp500, spla40

# %%
from typing import Any, Dict
import re
import pandas as pd


# ============================================================================
# TEXT CLEANING & CONTEXT BUILDING FOR LLM
# ============================================================================

def clean_text(text: Any) -> str:
    """
    Clean and normalize text for LLM input.
    Removes Wikipedia markup and normalizes whitespace.
    """
    if pd.isna(text) or text is None:
        return ""

    text = str(text)

    # Handle common Wikipedia templates by extracting useful content
    # {{US$|24.58 billion|...}} -> $24.58 billion
    text = re.sub(r"\{\{US\$\|([^}|]+)[^}]*\}\}", r"$\1", text)

    # {{circa|61,500}} -> ~61,500
    text = re.sub(r"\{\{circa\|([^}|]+)[^}]*\}\}", r"~\1", text)

    # {{increase}}, {{decrease}} -> arrows
    text = re.sub(r"\{\{increase\}\}", "↑", text)
    text = re.sub(r"\{\{decrease\}\}", "↓", text)

    # {{Start date and age|1902|6|13}} -> 1902-06-13
    text = re.sub(
        r"\{\{Start date and age\|(\d+)\|(\d+)\|(\d+)[^}]*\}\}",
        r"\1-\2-\3",
        text,
    )

    # {{URL|example.com}} -> example.com
    text = re.sub(r"\{\{URL\|([^}|]+)[^}]*\}\}", r"\1", text)

    # {{plainlist|...}} and {{Unbulleted list|...}} - extract items
    text = re.sub(r"\{\{(?:plainlist|Unbulleted list)\|", "", text)

    # Remove remaining templates iteratively (handles nesting)
    prev_text = ""
    while prev_text != text:
        prev_text = text
        text = re.sub(r"\{\{[^{}]*\}\}", "", text)

    # Extract text from wiki links [[text|display]] -> display or [[text]] -> text
    text = re.sub(r"\[\[([^|\]]*\|)?([^\]]+)\]\]", r"\2", text)

    # Remove reference tags
    text = re.sub(r"<ref[^>]*>.*?</ref>", "", text, flags=re.DOTALL)
    text = re.sub(r"<ref[^/]*/?>", "", text)
    text = re.sub(r"</ref>", "", text)
    text = re.sub(r"<[^>]+>", "", text)

    # Clean up remaining brackets, braces, pipes, asterisks
    text = re.sub(r"[\[\]{}|*]", "", text)

    # Normalize whitespace
    text = re.sub(r"\s+", " ", text).strip()

    return text


def extract_key_facts(row: pd.Series) -> Dict[str, str]:
    """
    Extract key facts from a company infobox row.
    Uses case-insensitive matching to handle Wikipedia's varying field names.
    """
    field_mappings = {
        "name": ["name", "_company_name", "company_name"],
        "type": ["type"],
        "industry": ["industry", "industries"],
        "founded": ["foundation", "founded", "established"],
        "founder": ["founder", "founders"],
        "headquarters": [
            "hq_location",
            "headquarters",
            "location_city",
            "hq_location_city",
        ],
        "country": ["location_country", "hq_location_country", "country"],
        "key_people": ["key_people", "ceo", "chairman"],
        "employees": ["num_employees", "employees"],
        "revenue": ["revenue"],
        "website": ["website", "url", "homepage"],
    }

    # Create lowercase column mapping
    col_lower = {col.lower(): col for col in row.index}

    facts: Dict[str, str] = {}
    for field, possible_names in field_mappings.items():
        for name in possible_names:
            if name in col_lower:
                value = row[col_lower[name]]
                cleaned = clean_text(value)
                if cleaned:
                    facts[field] = cleaned
                    break

    return facts


def row_to_context(row: pd.Series) -> str:
    """
    Convert a company row into a formatted context string for LLM input.
    """
    facts = extract_key_facts(row)

    if not facts:
        return "No company information available."

    lines = ["COMPANY INFORMATION", "-" * 40]

    field_order = [
        "name",
        "type",
        "industry",
        "founded",
        "founder",
        "headquarters",
        "country",
        "key_people",
        "employees",
        "revenue",
        "website",
    ]

    for field in field_order:
        if field in facts:
            label = field.replace("_", " ").title()
            lines.append(f"{label}: {facts[field]}")

    return "\n".join(lines)


# ============================================================================
# HIGHER-LEVEL WRAPPERS
# ============================================================================

def add_llm_context_column(df: pd.DataFrame) -> pd.DataFrame:
    """
    Return a copy of df with an extra column 'llm_context'
    containing the formatted context for each row.
    """
    df = df.copy()
    df["llm_context"] = df.apply(row_to_context, axis=1)
    return df


def preprocess_infobox_dict(
    infobox_data: Dict[str, pd.DataFrame]
) -> Dict[str, pd.DataFrame]:
    """
    Given a dict of {index_name: DataFrame}, return a new dict where
    each DataFrame has an added 'llm_context' column.
    """
    return {name: add_llm_context_column(df) for name, df in infobox_data.items()}


# ============================================================================
# DEMO / PREVIEW UTIL
# ============================================================================

def demo_preprocessing_for_index(
    infobox_data: Dict[str, pd.DataFrame],
    index_name: str = "sp500",
) -> None:
    """
    Show how cleaning and context-building work on the first row
    of a given index:
      - raw vs cleaned fields
      - extracted key facts
      - final LLM context block
    """
    if index_name not in infobox_data:
        print(
            f"❌ Index '{index_name}' not found in infobox_data.\n"
            f"   Available indexes: {list(infobox_data.keys())}"
        )
        return

    df = infobox_data[index_name]
    if df.empty:
        print(f"⚠️ DataFrame for index '{index_name}' is empty.")
        return

    sample_row = df.iloc[0]

    print("\n" + "=" * 70)
    print(f" DEMO: PREPROCESSING FOR INDEX '{index_name.upper()}'")
    print("=" * 70)

    # 1) Raw vs cleaned example fields
    print("\n[1] RAW vs CLEANED FIELDS")
    print("-" * 70)
    for col in ["revenue", "num_employees", "foundation"]:
        if col in sample_row.index:
            print(f"\n• Column: {col}")
            print(f"  Raw:    {sample_row[col]}")
            print(f"  Cleaned:{' ' if clean_text(sample_row[col]) else ''}{clean_text(sample_row[col])}")

    # 2) Extracted key facts
    print("\n" + "-" * 70)
    print("[2] EXTRACTED KEY FACTS")
    print("-" * 70)
    facts = extract_key_facts(sample_row)
    if not facts:
        print("No key facts extracted.")
    else:
        for k, v in facts.items():
            print(f"  - {k}: {v}")

    # 3) Final LLM context
    print("\n" + "-" * 70)
    print("[3] FORMATTED CONTEXT FOR LLM")
    print("-" * 70)
    context = row_to_context(sample_row)
    print(context)

    print("\n" + "=" * 70)
    print(" END OF DEMO")
    print("=" * 70)


# ============================================================================
# TEST / USAGE EXAMPLE
# ============================================================================

# Supposons que tu aies déjà :
# infobox_data = load_and_analyze_infobox_data()

# 1. Add LLM context column to a single dataframe
sp500_with_context = add_llm_context_column(infobox_data["sp500"])

# 2. Add LLM context to all indexes in one go
infobox_with_context = preprocess_infobox_dict(infobox_data)

# 3. Run a demo on SP500
demo_preprocessing_for_index(infobox_data, index_name="sp500")
# Out:
# ======================================================================
#  DEMO: PREPROCESSING FOR INDEX 'SP500'
# ======================================================================
#
# [1] RAW vs CLEANED FIELDS
# ----------------------------------------------------------------------
#
# • Column: revenue
#   Raw:    {{decrease}} {{US$|24.58 billion|link|=|yes}} (2024)
#   Cleaned: ↓ $24.58 billion (2024)
#
# • Column: num_employees
#   Raw:    {{circa|61,500}} (2024)
#   Cleaned: ~61,500 (2024)
#
# • Column: foundation
#   Raw:    {{Start date and age|1902|6|13}} in [[Two Harbors, Minnesota]], U.S.
#   Cleaned: 1902-6-13 in Two Harbors, Minnesota, U.S.
#
# ----------------------------------------------------------------------
# [2] EXTRACTED KEY FACTS
# ----------------------------------------------------------------------
#   - name: 3M Company
#   - type: Public
#   - industry: Conglomerate
#   - founded: 1902-6-13 in Two Harbors, Minnesota, U.S.
#   - founder: J. Danley BuddHenry S. BryanWilliam A. McGonagleJohn DwanHermon W. Cable Charles Simmonsref
#   - headquarters: Maplewood, Minnesota
#   - country: U.S.
#   - key_people: Michael F. Roman (chairman) William M. Brown (CEO)ref
#   - employees: ~61,500 (2024)
#   - revenue: ↓ $24.58 billion (2024)
#   - website: 3m.com
#
# ----------------------------------------------------------------------
# [3] FORMATTED CONTEXT FOR LLM
# ----------------------------------------------------------------------
# COMPANY INFORMATION
# ----------------------------------------
# Name: 3M Company
# Type: Public
# Industry: Conglomerate
# Founded: 1902-6-13 in Two Harbors, Minnesota, U.S.
# Founder: J. Danley BuddHenry S. BryanWilliam A. McGonagleJohn DwanHermon W. Cable Charles Simmonsref
# Headquarters: Maplewood, Minnesota
# Country: U.S.
# Key People: Michael F. Roman (chairman) William M. Brown (CEO)ref
# Employees: ~61,500 (2024)
# Revenue: ↓ $24.58 billion (2024)
# Website: 3m.com
#
# ======================================================================
#  END OF DEMO
# ======================================================================

# %%
from typing import List


# ============================================================================
# PROMPT TEMPLATES FOR LLM TASKS
# ============================================================================

def qa_prompt(context: str, question: str) -> str:
    """
    Crée un prompt de Question/Réponse sur une entreprise.
    """
    return f"""You are a helpful assistant answering questions about companies.

{context}

Question: {question}

Please provide a clear, concise answer based only on the information provided above. If the information is not available, say so."""


def classification_prompt(context: str, categories: List[str]) -> str:
    """
    Crée un prompt pour classer une entreprise dans une catégorie.
    """
    categories_str = "\n".join(f"- {cat}" for cat in categories)

    return f"""You are a business analyst classifying companies into categories.

{context}

Based on the company information above, classify this company into ONE of the following categories:
{categories_str}

Respond with ONLY the category name, followed by a brief one-sentence justification."""


def summarization_prompt(context: str) -> str:
    """
    Crée un prompt de résumé d'informations d’entreprise.
    """
    return f"""You are a business analyst creating company summaries.

{context}

Please provide a concise 2-3 sentence summary of this company, highlighting:
1. What the company does (industry/business)
2. Key characteristics (size, location, notable facts)
3. Any distinguishing features

Keep the summary factual and professional."""


def comparison_prompt(context1: str, context2: str) -> str:
    """
    Crée un prompt de comparaison entre deux entreprises.
    """
    return f"""You are a business analyst comparing companies.

=== COMPANY 1 ===
{context1}

=== COMPANY 2 ===
{context2}

Please compare these two companies across the following dimensions:
1. Industry & Business Focus
2. Size & Scale (employees, revenue if available)
3. Geographic Presence
4. Key Similarities
5. Key Differences

Provide a structured comparison with clear insights."""


def extraction_prompt(context: str, fields: List[str]) -> str:
    """
    Crée un prompt pour extraire certains champs sous forme de JSON.
    """
    fields_str = ", ".join(f'"{f}"' for f in fields)

    return f"""You are a data extraction specialist.

{context}

Extract the following fields from the company information above:
[{fields_str}]

Respond with a valid JSON object containing only these fields.
Use null for any field that cannot be determined from the information provided.

Example format:
{{
  "field1": "value1",
  "field2": "value2"
}}"""


# ============================================================================
# DEMO : show examples of prompts for one index
# ============================================================================

def _show_block(title: str):
    print("\n" + "=" * 60)
    print(f"{title}")
    print("=" * 60 + "\n")


def demo_prompts_for_index(
    infobox_data,
    index_name: str = "sp500",
):
    """
    Affiche des exemples de prompts (Q&A, classification, résumé, extraction,
    comparaison) construits à partir des premières lignes d'un index.
    """
    if index_name not in infobox_data:
        print(f"❌ Index '{index_name}' not found. Available: {list(infobox_data.keys())}")
        return

    df = infobox_data[index_name]
    if df.empty:
        print(f"⚠️ DataFrame for index '{index_name}' is empty.")
        return

    # Contexte pour la première entreprise
    sample_context = row_to_context(df.iloc[0])

    print("\n" + "=" * 60)
    print(f" DEMO PROMPTS FOR INDEX: {index_name.upper()}")
    print("=" * 60)

    # 1. Q&A
    _show_block("[1] Q&A PROMPT")
    qa = qa_prompt(sample_context, "What industry is this company in?")
    print(qa)

    # 2. Classification
    _show_block("[2] CLASSIFICATION PROMPT")
    categories = ["Technology", "Healthcare", "Finance", "Industrial", "Consumer Goods"]
    classification = classification_prompt(sample_context, categories)
    print(classification)

    # 3. Summarization
    _show_block("[3] SUMMARIZATION PROMPT")
    summary = summarization_prompt(sample_context)
    print(summary)

    # 4. Extraction
    _show_block("[4] EXTRACTION PROMPT")
    fields = ["company_name", "industry", "employee_count", "annual_revenue"]
    extraction = extraction_prompt(sample_context, fields)
    print(extraction)

    # 5. Comparison (needs at least 2 companies)
    if len(df) >= 2:
        _show_block("[5] COMPARISON PROMPT")
        context2 = row_to_context(df.iloc[1])
        comparison = comparison_prompt(sample_context, context2)
        print(comparison)
    else:
        print("\n⚠️ Not enough rows for comparison prompt (need at least 2).")

    print("\n" + "=" * 60)
    print(" END OF PROMPT DEMO")
    print("=" * 60)


# ============================================================================
# USAGE EXAMPLE (in Colab)
# ============================================================================

# Suppose you already have:
# - infobox_data = load_and_analyze_infobox_data()
# - row_to_context defined

demo_prompts_for_index(infobox_data, index_name="sp500")
# Out:
# ============================================================
#  DEMO PROMPTS FOR INDEX: SP500
# ============================================================
#
# ============================================================
# [1] Q&A PROMPT
# ============================================================
#
# You are a helpful assistant answering questions about companies.
#
# COMPANY INFORMATION
# ----------------------------------------
# Name: 3M Company
# Type: Public
# Industry: Conglomerate
# Founded: 1902-6-13 in Two Harbors, Minnesota, U.S.
# Founder: J. Danley BuddHenry S. BryanWilliam A. McGonagleJohn DwanHermon W. Cable Charles Simmonsref
# Headquarters: Maplewood, Minnesota
# Country: U.S.
# Key People: Michael F. Roman (chairman) William M. Brown (CEO)ref
# Employees: ~61,500 (2024)
# Revenue: ↓ $24.58 billion (2024)
# Website: 3m.com
#
# Question: What industry is this company in?
#
# Please provide a clear, concise answer based only on the information provided above. If the information is not available, say so.
#
# ============================================================
# [2] CLASSIFICATION PROMPT
# ============================================================
#
# You are a business analyst classifying companies into categories.
#
# COMPANY INFORMATION
# ----------------------------------------
# Name: 3M Company
# Type: Public
# Industry: Conglomerate
# Founded: 1902-6-13 in Two Harbors, Minnesota, U.S.
# Founder: J. Danley BuddHenry S. BryanWilliam A. McGonagleJohn DwanHermon W. Cable Charles Simmonsref
# Headquarters: Maplewood, Minnesota
# Country: U.S.
# Key People: Michael F. Roman (chairman) William M. Brown (CEO)ref
# Employees: ~61,500 (2024)
# Revenue: ↓ $24.58 billion (2024)
# Website: 3m.com
#
# Based on the company information above, classify this company into ONE of the following categories:
# - Technology
# - Healthcare
# - Finance
# - Industrial
# - Consumer Goods
#
# Respond with ONLY the category name, followed by a brief one-sentence justification.
#
# ============================================================
# [3] SUMMARIZATION PROMPT
# ============================================================
#
# You are a business analyst creating company summaries.
#
# COMPANY INFORMATION
# ----------------------------------------
# Name: 3M Company
# Type: Public
# Industry: Conglomerate
# Founded: 1902-6-13 in Two Harbors, Minnesota, U.S.
# Founder: J. Danley BuddHenry S. BryanWilliam A. McGonagleJohn DwanHermon W. Cable Charles Simmonsref
# Headquarters: Maplewood, Minnesota
# Country: U.S.
# Key People: Michael F. Roman (chairman) William M. Brown (CEO)ref
# Employees: ~61,500 (2024)
# Revenue: ↓ $24.58 billion (2024)
# Website: 3m.com
#
# Please provide a concise 2-3 sentence summary of this company, highlighting:
# 1. What the company does (industry/business)
# 2. Key characteristics (size, location, notable facts)
# 3. Any distinguishing features
#
# Keep the summary factual and professional.
#
# ============================================================
# [4] EXTRACTION PROMPT
# ============================================================
#
# You are a data extraction specialist.
#
# COMPANY INFORMATION
# ----------------------------------------
# Name: 3M Company
# Type: Public
# Industry: Conglomerate
# Founded: 1902-6-13 in Two Harbors, Minnesota, U.S.
# Founder: J. Danley BuddHenry S. BryanWilliam A. McGonagleJohn DwanHermon W. Cable Charles Simmonsref
# Headquarters: Maplewood, Minnesota
# Country: U.S.
# Key People: Michael F. Roman (chairman) William M. Brown (CEO)ref
# Employees: ~61,500 (2024)
# Revenue: ↓ $24.58 billion (2024)
# Website: 3m.com
#
# Extract the following fields from the company information above:
# ["company_name", "industry", "employee_count", "annual_revenue"]
#
# Respond with a valid JSON object containing only these fields.
# Use null for any field that cannot be determined from the information provided.
#
# Example format:
# {
#   "field1": "value1",
#   "field2": "value2"
# }
#
# ============================================================
# [5] COMPARISON PROMPT
# ============================================================
#
# You are a business analyst comparing companies.
#
# === COMPANY 1 ===
# COMPANY INFORMATION
# ----------------------------------------
# Name: 3M Company
# Type: Public
# Industry: Conglomerate
# Founded: 1902-6-13 in Two Harbors, Minnesota, U.S.
# Founder: J. Danley BuddHenry S. BryanWilliam A. McGonagleJohn DwanHermon W. Cable Charles Simmonsref
# Headquarters: Maplewood, Minnesota
# Country: U.S.
# Key People: Michael F. Roman (chairman) William M. Brown (CEO)ref
# Employees: ~61,500 (2024)
# Revenue: ↓ $24.58 billion (2024)
# Website: 3m.com
#
# === COMPANY 2 ===
# COMPANY INFORMATION
# ----------------------------------------
# Name: A. O. Smith Corporation
# Type: Public
# Industry: Water technology
# Founded: in Milwaukee, Wisconsin, U.S.
# Founder: Charles Jeremiah Smith
# Headquarters: Milwaukee, Wisconsin
# Country: U.S.
# Key People: (chairman, president & CEO)
# Employees: 12,700
# Revenue: ↓ $3.82 &nbsp;billion (2024)
#
# Please compare these two companies across the following dimensions:
# 1. Industry & Business Focus
# 2. Size & Scale (employees, revenue if available)
# 3. Geographic Presence
# 4. Key Similarities
# 5. Key Differences
#
# Provide a structured comparison with clear insights.
#
# ============================================================
#  END OF PROMPT DEMO
# ============================================================

# %% [markdown]
# Create a PromptBuilder class with different methods for creating prompts:
# - qa prompt
# - classification prompt
# - summarization prompt
# - comparison prompt
# - information extraction prompt

# %%
"""
LLM BEST PRACTICES — CLEAN OVERVIEW
-----------------------------------

1. Context Preparation
   - Keep context focused, relevant, and clean
   - Standardize text and remove ambiguous parts
   - Add source metadata when available

2. Prompt Design
   - Use clear, specific task instructions
   - Include examples where helpful
   - Define expected output formats precisely
   - Assign a model role for better consistency

Applications of Company Data:
   - Industry classification
   - Market and competitor analysis
   - Risk assessment
   - Investment profiling
   - Data enrichment from Wikipedia
   - Report and summary generation
   - Extraction of structured information
   - Reputation and sentiment insights
   - Trend and pattern detection
   - Peer comparison and benchmarking
"""
# Out:
# '\nLLM BEST PRACTICES — CLEAN OVERVIEW\n-----------------------------------\n\n1. Context Preparation\n   - Keep context focused, relevant, and clean\n   - Standardize text and remove ambiguous parts\n   - Add source metadata when available\n\n2. Prompt Design\n   - Use clear, specific task instructions\n   - Include examples where helpful\n   - Define expected output formats precisely\n   - Assign a model role for better consistency\n\nApplications of Company Data:\n   - Industry classification\n   - Market and competitor analysis\n   - Risk assessment\n   - Investment profiling\n   - Data enrichment from Wikipedia\n   - Report and summary generation\n   - Extraction of structured information\n   - Reputation and sentiment insights\n   - Trend and pattern detection\n   - Peer comparison and benchmarking\n'

# %% [markdown]
# 🚀 NEXT STEPS (in anticipation of the final lab)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 1. Export your full dataset using PromptExporter
# 2. Test prompts with a small sample (5-10 companies)
# 3. Evaluate LLM outputs for quality and accuracy
# 4. Iterate on prompts based on results
# 5. Scale up to full dataset using batch APIs
# 6. Monitor token usage and costs
# 7. Implement feedback loops for continuous improvement
# 8. Build evaluation metrics for output quality
